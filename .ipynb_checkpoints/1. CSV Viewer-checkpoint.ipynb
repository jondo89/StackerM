# %%
import pandas as pd
import matplotlib.pyplot as plt
FileName = '03-06-2022_03-41-15-407.csv'
# Load the CSV file into a Pandas dataframe
df = pd.read_csv('./csv/'+FileName, delimiter=';', encoding="utf-8-sig")

# View the first few rows of the dataframe

# Plot the time series data
plt.plot(df.index, df['Channel 2.2'])

# Set plot title and axis labels
plt.title(FileName)
plt.xlabel('Time')
plt.ylabel('Value')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
FileName = '04-06-2022_03-41-15-525.csv'
# Load the CSV file into a Pandas dataframe
df = pd.read_csv('./csv/'+FileName, delimiter=';', encoding="utf-8-sig")

# View the first few rows of the dataframe

# Plot the time series data
plt.plot(df.index, df['Channel 2.2'])

# Set plot title and axis labels
plt.title(FileName)
plt.xlabel('Time')
plt.ylabel('Value')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
FileName = '03-06-2022_15-41-15-465.csv'
# Load the CSV file into a Pandas dataframe
df = pd.read_csv('./csv/'+FileName, delimiter=';', encoding="utf-8-sig")

# View the first few rows of the dataframe

# Plot the time series data
plt.plot(df.index, df['Channel 2.2'])

# Set plot title and axis labels
plt.title(FileName)
plt.xlabel('Time')
plt.ylabel('Value')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
FileName = '03-06-2022_21-41-15-487.csv'
# Load the CSV file into a Pandas dataframe
df = pd.read_csv('./csv/'+FileName, delimiter=';', encoding="utf-8-sig")

# View the first few rows of the dataframe

# Plot the time series data
plt.plot(df.index, df['Channel 2.2'])

# Set plot title and axis labels
plt.title(FileName)
plt.xlabel('Time')
plt.ylabel('Value')

# Show the plot
plt.show()
