# %%
########################################## FINES STACKER - KOLOMELA ##########################################

# %%
#INSTRUCTIONS:
#1. Ensure the CSV's have been pushed to the Mongocloud. 

#Google Drive Functional Spec
#https://docs.google.com/document/d/1DxqJCOKn40OIKej5CaKQ3CNnHxVCJO3I2LFPDUv4V0I/edit#

#User Manual
#https://docs.google.com/document/d/1qL2m3qvlNFPelwpigaVLsu8i0OQEmeqqw3ghwsF5W4E/edit?usp=sharing

# %%
#Troubleshooting notes
#1. When loading modules, they remain loaded on the page , and deleteing the import can cause unexpected errors.
#2. a .env file with passwords etc is required for mongodb access.

# %%
#Required tests.
#1.Review and confirm the Weld class and Guage factor calcuation as well as the values . 
#2.The newly installed gagues have lower guage factors.
#3.Work was done to understand the use of filtering , however this was discarded , and not well documented. Review the forward and F/b pass filterin.

# %%
machine = "fines"
path = 'C:/Users/jdavi/Desktop/Fines April/e/'

# %%
#This is a file stream function , and as such requries a "promise" for inline code, wont work in the cell as is below. 
from pathlib import Path#This is a file stream function , and as such requries a "promise" for inline code, wont work in the cell as is below. 
from pathlib import Path
from dotenv import load_dotenv # add this line
import os
env_path = Path('.') / '.env'
load_dotenv(dotenv_path=env_path)

THIS_MACHINE_ENV = os.getenv('THIS_MACHINE_ENV')

if(THIS_MACHINE_ENV != machine):
    print("TEST FAIL : .ENV is incorrect or out of date.")

# A missing or out-of-date .env file can cause errors in a software project.
# The .env file stores important configuration information and environment variables needed for the software to function correctly.
# If this information is missing or incorrect, the software may not be able to connect to databases or third-party services, or may not be able to access other critical resources.
# For example, in a Node.js application, if a database connection string is stored in the .env file and the file is missing or contains an outdated connection string, the application will not be able to connect to the database, causing errors or failure to function correctly.
# Similarly, if an API key or other authentication credentials are stored in the .env file and are missing or out-of-date, the software may not be able to authenticate with third-party services or may be denied access to critical resources.
# In summary, the .env file is a critical component of many software projects that store sensitive data and configurations. It should be kept up-to-date and include all necessary environment variables to ensure the software functions correctly.
from dotenv import load_dotenv # add this line
env_path = Path('.') / '.env'
load_dotenv(dotenv_path=env_path)
# Out:
# True

# %%
#CONNECT TO REMOTE MONGODB  
import pymongo #import the pymongo pip
import datetime #pip module for handling date and time
from pymongo import MongoClient #mongodb management
import os
import certifi #pip module for SSL certificates
user = os.getenv('MYSQL_USER')
userPC = os.environ['COMPUTERNAME'] # WORK ONLY ON WINDOWS
password = os.getenv('MYSQL_PASSWORD')
host = os.getenv('MYSQL_HOST')
COLLECTIONCSVFILES = os.getenv('COLLECTIONCSVFILES')
conn_text = 'mongodb+srv://{}:{}@{}/?retryWrites=true&w=majority'.format(user,password,host)
client = MongoClient(conn_text, tlsCAFile=certifi.where())
db = client.entangelment
collection = db[COLLECTIONCSVFILES]

# Adjust the MongoDB query to filter for documents where the "comment" field matches the "path" variable
query = {"comment": path}

# Use the find() method instead of find_one() to get all matching documents
dataset = list(collection.find(query).sort('_id', pymongo.DESCENDING))

# Check if the query returned more than one document
if len(dataset) > 1:
    raise ValueError("The query returned more than one document. Please adjust the query to return a single document.")

# If the query returned exactly one document, proceed with the rest of the code
dataset = dataset[0]

mainarray = {} #initialize the main array

#  PRINT THE LIST BOX FOR PROCESSING 
import ipywidgets as widgets

filenamelist = [] #initialize the csv array of filenames
channels = ['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4', 'Channel 2.1', 'Channel 2.2', 'Channel 2.3', 'Channel 2.4']
for i in dataset['date']: #create a list of filenames.
    dataloop = i['filename']
    filenamelist.append(dataloop)
mainarray = {
  "File Name": filenamelist,
  "Channel": channels
}
print(mainarray)
print("Receive CSV list from Server - Complete")
# Out:
# {'File Name': ['22-04-2023_00-34-45-412.csv', '22-04-2023_06-34-45-449.csv', '22-04-2023_12-34-45-489.csv', '22-04-2023_18-34-45-528.csv', '23-04-2023_00-34-45-568.csv', '23-04-2023_06-34-45-592.csv', '23-04-2023_12-34-45-627.csv', '23-04-2023_18-34-45-650.csv', '24-04-2023_00-34-45-687.csv', '24-04-2023_06-34-45-710.csv', '24-04-2023_12-34-45-750.csv', '24-04-2023_18-34-45-788.csv', '25-04-2023_00-34-45-811.csv', '25-04-2023_06-34-45-846.csv', '25-04-2023_12-34-45-871.csv', '25-04-2023_21-12-38-351.csv', '26-04-2023_03-12-38-390.csv', '26-04-2023_09-12-38-411.csv', '26-04-2023_19-25-13-456.csv', '27-04-2023_01-25-13-496.csv', '27-04-2023_07-25-13-536.csv', '27-04-2023_16-36-51-384.csv', '27-04-2023_22-36-51-405.csv', '28-04-2023_04-36-51-427.csv', '28-04-2023_10-36-51-463.csv', '28-04-2023_16-36-51-503.csv', '28-04-2023_22-36-51-527.csv', '29-04-2023_04-36-51-565.csv', '29-04-2023_10-36-51-586.csv', '29-04-2023_16-36-51-623.csv'], 'Channel': ['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4', 'Channel 2.1', 'Channel 2.2', 'Channel 2.3', 'Channel 2.4']}
# Receive CSV list from Server - Complete

# %%
# Importing Modules
import numpy as np
import pandas
import glob # module for reading files from a directory
import os # module for getting only the filename not the whole path
from datetime import datetime
from datetime import datetime, timedelta 
import csv
import json
    
########### GLOBAL VARIABLES 
Files =[]
JSONStructure = []
Channels = [] 
tempVar= []
tempVar2= []
 
########  CONSTRUCT JSON OBJECT FOR DATA PROCESSING 
filecount = len([name for name in os.listdir(path) if os.path.isfile(os.path.join(path, name))])
for i in range(len(mainarray['File Name'])):
    Files.append(path+mainarray['File Name'][i])
    with open(path+mainarray['File Name'][i]) as file:
        print(path+mainarray['File Name'][i] +" "+ str(i) + "/" + str(filecount))
        x = pandas.read_csv(file, delimiter=';',low_memory=False)#read in each CSV file
        #Extract the start and end times on each CSV file
        startTime= str(x.iloc[[0]]['Time'].values[0]) # string extract of start and end times for CSV
        EndTime= str(x.iloc[[-5]]['Time'].values[0]) # string extract of start and end times for CSV
        if startTime[11:13] =='24':
            #print(int(startTime[11:13]))
            startTime= str(0)+str(int(startTime[:1])+1)+startTime[2:10]+"_"+str(startTime[11:13].replace("24","00"))+"-"+startTime[14:]
        if EndTime[11:13] =='24':
            #print(int(EndTime[11:13])+1)
            EndTime= str(0)+ str(int(EndTime[:1])+1)+EndTime[2:10]+"_"+str(EndTime[11:13].replace("24","00"))+"-"+EndTime[14:]
        dateObject = str(startTime[0:10]).replace("-", " ")
        timeObject = str(startTime[11:19]).replace("-", " ")
        total = dateObject+' '+timeObject
        dateObject = datetime.strptime(total, '%d %m %Y %H %M %S')
        startTimeStr = str(dateObject)
        startTime = dateObject
        dateObject = str(EndTime[0:10]).replace("-", " ")
        timeObject = str(EndTime[11:19]).replace("-", " ")
        total = dateObject+' '+timeObject
        dateObject = datetime.strptime(total, '%d %m %Y %H %M %S')
        EndTimeStr = str(dateObject)
        EndTime = dateObject
        duration = EndTime - startTime
        if duration.days == 1:
            duration=duration-timedelta(days=1)
        if duration.days == -1:
            duration=duration+timedelta(days=1) 
        if duration.days == 2:
            duration=duration-timedelta(days=2)
        tempVarArray= []
        for Channel in mainarray['Channel']:
            Channel = Channel.strip('\"')
            Channels.append(Channel)        
            tempVar =   { 'Channel Name':Channel,
                        }
            tempVarArray.append(tempVar)
        tempVar2 = {
            "File" : {
                    'file name':mainarray['File Name'][i],
                    "Duration": str(duration),
                    "Channel Data" : tempVarArray,
                    }
        }               
        JSONStructure.append(tempVar2)
        #file.close()
#NFI
Channels = list(dict.fromkeys(Channels)) # remove duplicates inside the channel list
print("complete")
# Out:
# C:/Users/jdavi/Desktop/Fines April/e/22-04-2023_00-34-45-412.csv 0/30
# C:/Users/jdavi/Desktop/Fines April/e/22-04-2023_06-34-45-449.csv 1/30
# C:/Users/jdavi/Desktop/Fines April/e/22-04-2023_12-34-45-489.csv 2/30
# C:/Users/jdavi/Desktop/Fines April/e/22-04-2023_18-34-45-528.csv 3/30
# C:/Users/jdavi/Desktop/Fines April/e/23-04-2023_00-34-45-568.csv 4/30
# C:/Users/jdavi/Desktop/Fines April/e/23-04-2023_06-34-45-592.csv 5/30
# C:/Users/jdavi/Desktop/Fines April/e/23-04-2023_12-34-45-627.csv 6/30
# C:/Users/jdavi/Desktop/Fines April/e/23-04-2023_18-34-45-650.csv 7/30
# C:/Users/jdavi/Desktop/Fines April/e/24-04-2023_00-34-45-687.csv 8/30
# C:/Users/jdavi/Desktop/Fines April/e/24-04-2023_06-34-45-710.csv 9/30
# C:/Users/jdavi/Desktop/Fines April/e/24-04-2023_12-34-45-750.csv 10/30
# C:/Users/jdavi/Desktop/Fines April/e/24-04-2023_18-34-45-788.csv 11/30
# C:/Users/jdavi/Desktop/Fines April/e/25-04-2023_00-34-45-811.csv 12/30
# C:/Users/jdavi/Desktop/Fines April/e/25-04-2023_06-34-45-846.csv 13/30
# C:/Users/jdavi/Desktop/Fines April/e/25-04-2023_12-34-45-871.csv 14/30
# C:/Users/jdavi/Desktop/Fines April/e/25-04-2023_21-12-38-351.csv 15/30
# C:/Users/jdavi/Desktop/Fines April/e/26-04-2023_03-12-38-390.csv 16/30
# C:/Users/jdavi/Desktop/Fines April/e/26-04-2023_09-12-38-411.csv 17/30
# C:/Users/jdavi/Desktop/Fines April/e/26-04-2023_19-25-13-456.csv 18/30
# C:/Users/jdavi/Desktop/Fines April/e/27-04-2023_01-25-13-496.csv 19/30
# C:/Users/jdavi/Desktop/Fines April/e/27-04-2023_07-25-13-536.csv 20/30
# C:/Users/jdavi/Desktop/Fines April/e/27-04-2023_16-36-51-384.csv 21/30
# C:/Users/jdavi/Desktop/Fines April/e/27-04-2023_22-36-51-405.csv 22/30
# C:/Users/jdavi/Desktop/Fines April/e/28-04-2023_04-36-51-427.csv 23/30
# C:/Users/jdavi/Desktop/Fines April/e/28-04-2023_10-36-51-463.csv 24/30
# C:/Users/jdavi/Desktop/Fines April/e/28-04-2023_16-36-51-503.csv 25/30
# C:/Users/jdavi/Desktop/Fines April/e/28-04-2023_22-36-51-527.csv 26/30
# C:/Users/jdavi/Desktop/Fines April/e/29-04-2023_04-36-51-565.csv 27/30
# C:/Users/jdavi/Desktop/Fines April/e/29-04-2023_10-36-51-586.csv 28/30
# C:/Users/jdavi/Desktop/Fines April/e/29-04-2023_16-36-51-623.csv 29/30
# complete

# %%
#Importing Modules 
import matplotlib.pyplot as plt
import numpy as np
from math import pi
import scipy.fftpack as sf
import scipy.signal as sig
import rainflow
import pandas
import glob # module for reading files from a directory
import os # module for getting only the filename not the whole path
from pylab import*
import json
import csv

#DEFINE GLOBAL VARIABLES
Slot1=['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4'] 
Files =[] # empty array to store Files
ChannelData = []

Corr1 = 0.1840265*0.207 # Channel 1.1 to 1.4 weld class W
Corr2 = 0.4784689*0.207 # Channel 2.1 to 2.4 weld class F2    

#Create a Low Path Filter
# filter response
#[W,h] = sig.freqz(b,a, worN=1024)
#W = Fs* W/(2*pi)
Fs = 50;
o = 8;
fc = np.array([14]) #Cut Off Frequncy
wc = 2*fc/Fs;
[b,a] = sig.butter(o, wc, btype = 'lowpass')

#BUILD FILE LIST FOR PROCESSING
Files=[]
for i in range(len(mainarray['File Name'])):
    Files.append(mainarray['File Name'][i])

# %%
#   MODIFY CHANNEL RAW DATA BY WELD CLASS  
#Take actual data in CSV , and multiply line by line with the Correction factors.

def modifyChannelDataintoStress(Channel):
    ChannelData ={
                            'actualData' :Channel,
                            'stressData' :[]
                        }   
    if Channel.name in Slot1:
        for actualData in Channel :
            if str(actualData) !='nan':
                modifiedData = float(actualData)*Corr1 
                ChannelData['stressData'].append(modifiedData)
            else:
                print('nan erros here , too many should be investigated.')
    else:
        for actualData in Channel:
            if str(actualData) !='nan':
                modifiedData = float(actualData)*Corr2
                ChannelData['stressData'].append(modifiedData)
            else:
                print('nan erros here , too many should be investigated.')
    return ChannelData

# %%
#Package The Filtered Signal
def FilteredSignal(Channel):
    #Work was done here to understand the use of filtering , however this was discarded , and not well documented.
    #At this point , there is no signal filtering , only date as modified in the getchannel data.
    #x_filt = sig.filtfilt(b,a, GetChannelData(Channel)) # forward and backward
    #x_filt = sig.lfilter(b,a, GetChannelData(Channel)) # Forward only
    x_filt =  modifyChannelDataintoStress(Channel) #turn data into stress with correction factors
    TimeLength=len(x_filt['stressData'])#get list count
    seq=[round(x,1) for x in range(1, TimeLength+1)] #create a running count from 0
    hz = 0.02 #1/0.02 = 50Hz capture rate of PMX
    x2= [round(x*hz,3) for x in range(0, TimeLength)]#this is create frequency time steps. it is a division of time
    dataFrameOfStressData={'count':seq,'timestep':x2,'stressData':x_filt['stressData'],'actualData':x_filt['actualData']}
    dataFrameOfStressData= pandas.DataFrame(dataFrameOfStressData, columns=['count','timestep', 'stressData','actualData'])
   
    #plot stress data
    t=dataFrameOfStressData['timestep']
    s2=dataFrameOfStressData['stressData']
    s3=dataFrameOfStressData['actualData']
 
    #plt.plot(t, s2,t, s3) # plot the filtered results.  
    #plt.xlabel("Time (s)")
    #plt.ylabel("Stress (MPa)")
    return dataFrameOfStressData

# %%
#RainFlow Counting
def RainFlow(Filtered, Channel):
    RainFlow_Results =[] #Initialize an empty list to store the results of Rainflow Algorithm
    x = Filtered.timestep.tolist()
    y = round(Filtered['stressData'],3).tolist()
    # Rainflow Count Algorithm
    # Function count_cycles returns a sorted list of the load ranges and the corresponding number of cycles
    # 3 decimal digits is used for precision
    # Mean, Range , Cycle Count list use to store each point in 3-Dimension
    damage1 = 0 #50 % damage
    damage2 = 0 # 97.7 % damage
    # Detailed output, like cycle lows, highs or means, use extract_cycles
    for rng, mean, count, i_start, i_end in rainflow.extract_cycles(y): 
        # compute the 50 % damage 
        if rng != 0: # if the range is zero no computation
            if Channel in Slot1 :
                Nfw=10**(11.5662-3*np.log10(rng))
                Ni = (count/Nfw)*100
                damage1=damage1+Ni
            else:
                Nfw=10**(12.0900-3*np.log10(rng))
                Ni = (count/Nfw)*100
                damage1=damage1+Ni
            # Compute the 97.7 % damage
            if Channel in Slot1 :
                Nfw=10**(11.5662-0.1846*2-3*np.log10(rng))
                Ni = (count/Nfw)*100
                damage2=damage2+Ni
            else:
                Nfw=10**(12.090-0.2279*2-3*np.log10(rng))
                Ni = (count/Nfw)*100
                damage2=damage2+Ni
    print(Channel , ' dmg @50% prob. survival : ',damage1,' %', ' dmg @97.7% prob. survival : ',damage2,' %') 
    RainFlow_Results.append(damage1) # 50 % damage
    RainFlow_Results.append(damage2) # 97.7 % damage
    return RainFlow_Results

# %%
#Running the Script Section
#Reading CSV Files From Folder
#RawData = pandas.DataFrame() # Initialize an empty dataframe 
count = 0
for file_nameShort in Files:
    print(file_nameShort +" "+ str(count) + "/" + str(filecount))
    count = count+1
    with open(path+file_nameShort) as file:
        dataofCSV = pandas.read_csv(file, delimiter=';',low_memory=False, on_bad_lines='skip')
        dataofCSV = dataofCSV.drop(dataofCSV.tail(3).index)
        # Calling the function on each Filename
        for Channel in Channels:
            dataframeOfFilteredData = FilteredSignal(dataofCSV[Channel]) # call the filtering the data and output a dataframe
            ab2 = RainFlow(dataframeOfFilteredData,Channel) # using the filtered data return a list of damages 
            #Assign outputs to JSONStructure
            #1. Find the File name in the JSONStructure we are looking for.
            for i in JSONStructure:
                if i['File']['file name'] == file_nameShort:
                    #2. Find the Channel Name We are looking for in the JSONStructure.
                    for j in i['File']['Channel Data']:
                        if j['Channel Name'] == Channel:
                            #3. Assign the Data
                            j['50 Damage'] = ab2[0]
                            j['97 Damage'] = ab2[1]
                            j['Minimum Stress']=dataframeOfFilteredData.min()[2]
                            j['Maximum Stress']=dataframeOfFilteredData.max()[2] 
            file.close()
print("complete")
# Out:
# 22-04-2023_00-34-45-412.csv 0/30
# Channel 1.1  dmg @50% prob. survival :  1.9045790970022095e-08  %  dmg @97.7% prob. survival :  4.456552361757996e-08  %
# Channel 1.2  dmg @50% prob. survival :  3.2792527618274712e-09  %  dmg @97.7% prob. survival :  7.673171286779773e-09  %
# Channel 1.3  dmg @50% prob. survival :  4.341177058188217e-07  %  dmg @97.7% prob. survival :  1.015798341057315e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.212843941873814e-07  %  dmg @97.7% prob. survival :  2.837951199877145e-07  %
# Channel 2.1  dmg @50% prob. survival :  2.5068891152971145e-08  %  dmg @97.7% prob. survival :  7.160364400111993e-08  %
# Channel 2.2  dmg @50% prob. survival :  5.884053145032188e-05  %  dmg @97.7% prob. survival :  0.00016806473174638345  %
# Channel 2.3  dmg @50% prob. survival :  1.0959053240439961e-05  %  dmg @97.7% prob. survival :  3.1302068449269696e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.37584182649742e-07  %  dmg @97.7% prob. survival :  6.786057321377584e-07  %
# 22-04-2023_06-34-45-449.csv 1/30
# Channel 1.1  dmg @50% prob. survival :  6.0543469653779865e-06  %  dmg @97.7% prob. survival :  1.416665462196603e-05  %
# Channel 1.2  dmg @50% prob. survival :  5.319567969624345e-09  %  dmg @97.7% prob. survival :  1.2447334550641752e-08  %
# Channel 1.3  dmg @50% prob. survival :  5.968785697551855e-07  %  dmg @97.7% prob. survival :  1.3966448565513367e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.65628174561095e-07  %  dmg @97.7% prob. survival :  3.8755577737626187e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.2334531412947904e-07  %  dmg @97.7% prob. survival :  3.523081219762525e-07  %
# Channel 2.2  dmg @50% prob. survival :  8.441958660427186e-05  %  dmg @97.7% prob. survival :  0.0002411255443668287  %
# Channel 2.3  dmg @50% prob. survival :  1.5059142240145988e-05  %  dmg @97.7% prob. survival :  4.301304965368385e-05  %
# Channel 2.4  dmg @50% prob. survival :  4.276352102817747e-07  %  dmg @97.7% prob. survival :  1.2214437077605872e-06  %
# 22-04-2023_12-34-45-489.csv 2/30
# Channel 1.1  dmg @50% prob. survival :  3.813413117833241e-06  %  dmg @97.7% prob. survival :  8.923060881717523e-06  %
# Channel 1.2  dmg @50% prob. survival :  4.850017183051442e-09  %  dmg @97.7% prob. survival :  1.134862582798674e-08  %
# Channel 1.3  dmg @50% prob. survival :  6.046691246045912e-07  %  dmg @97.7% prob. survival :  1.414874089282219e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.6768646821083676e-07  %  dmg @97.7% prob. survival :  3.9237200865816624e-07  %
# Channel 2.1  dmg @50% prob. survival :  3.776448238818048e-08  %  dmg @97.7% prob. survival :  1.0786574229815095e-07  %
# Channel 2.2  dmg @50% prob. survival :  8.601734006884349e-05  %  dmg @97.7% prob. survival :  0.00024568916744774816  %
# Channel 2.3  dmg @50% prob. survival :  1.5089775960178618e-05  %  dmg @97.7% prob. survival :  4.310054797861194e-05  %
# Channel 2.4  dmg @50% prob. survival :  3.6390090221800644e-07  %  dmg @97.7% prob. survival :  1.0394010048184553e-06  %
# 22-04-2023_18-34-45-528.csv 3/30
# Channel 1.1  dmg @50% prob. survival :  1.84762446216534e-08  %  dmg @97.7% prob. survival :  4.32328338238377e-08  %
# Channel 1.2  dmg @50% prob. survival :  3.230948564268443e-09  %  dmg @97.7% prob. survival :  7.560143591551616e-09  %
# Channel 1.3  dmg @50% prob. survival :  4.235926265528362e-07  %  dmg @97.7% prob. survival :  9.911705548266396e-07  %
# Channel 1.4  dmg @50% prob. survival :  1.1808195000445869e-07  %  dmg @97.7% prob. survival :  2.763016742131301e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.3010908333484487e-08  %  dmg @97.7% prob. survival :  3.7162730603355425e-08  %
# Channel 2.2  dmg @50% prob. survival :  5.67264301853623e-05  %  dmg @97.7% prob. survival :  0.00016202627741529796  %
# Channel 2.3  dmg @50% prob. survival :  1.0585533454486272e-05  %  dmg @97.7% prob. survival :  3.0235193268489297e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.160807100478143e-07  %  dmg @97.7% prob. survival :  6.171859035709869e-07  %
# 23-04-2023_00-34-45-568.csv 4/30
# Channel 1.1  dmg @50% prob. survival :  1.848856818006692e-08  %  dmg @97.7% prob. survival :  4.326166989760824e-08  %
# Channel 1.2  dmg @50% prob. survival :  3.17692694956542e-09  %  dmg @97.7% prob. survival :  7.433737628696889e-09  %
# Channel 1.3  dmg @50% prob. survival :  4.2349673572599217e-07  %  dmg @97.7% prob. survival :  9.90946178484657e-07  %
# Channel 1.4  dmg @50% prob. survival :  1.1809810568351586e-07  %  dmg @97.7% prob. survival :  2.7633947712180313e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.7412778561665844e-08  %  dmg @97.7% prob. survival :  4.9735681949083997e-08  %
# Channel 2.2  dmg @50% prob. survival :  5.727571713105986e-05  %  dmg @97.7% prob. survival :  0.00016359519191869724  %
# Channel 2.3  dmg @50% prob. survival :  1.0611051671664281e-05  %  dmg @97.7% prob. survival :  3.0308080311127284e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.1618777750875633e-07  %  dmg @97.7% prob. survival :  6.174917176698126e-07  %
# 23-04-2023_06-34-45-592.csv 5/30
# Channel 1.1  dmg @50% prob. survival :  2.7100326615996157e-08  %  dmg @97.7% prob. survival :  6.341244885813968e-08  %
# Channel 1.2  dmg @50% prob. survival :  4.2907724803985025e-09  %  dmg @97.7% prob. survival :  1.0040041005055098e-08  %
# Channel 1.3  dmg @50% prob. survival :  5.796555576404197e-07  %  dmg @97.7% prob. survival :  1.3563444797188882e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.5963441425370977e-07  %  dmg @97.7% prob. survival :  3.735308903575472e-07  %
# Channel 2.1  dmg @50% prob. survival :  2.7377127529421974e-08  %  dmg @97.7% prob. survival :  7.819660157397833e-08  %
# Channel 2.2  dmg @50% prob. survival :  8.177756678506194e-05  %  dmg @97.7% prob. survival :  0.0002335792095319751  %
# Channel 2.3  dmg @50% prob. survival :  1.4333768875453346e-05  %  dmg @97.7% prob. survival :  4.094118393547535e-05  %
# Channel 2.4  dmg @50% prob. survival :  3.3393782030072816e-07  %  dmg @97.7% prob. survival :  9.53818206693121e-07  %
# 23-04-2023_12-34-45-627.csv 6/30
# Channel 1.1  dmg @50% prob. survival :  2.950931059855582e-08  %  dmg @97.7% prob. survival :  6.904926555626121e-08  %
# Channel 1.2  dmg @50% prob. survival :  4.4568252824567304e-09  %  dmg @97.7% prob. survival :  1.0428590374496723e-08  %
# Channel 1.3  dmg @50% prob. survival :  6.081173007705584e-07  %  dmg @97.7% prob. survival :  1.4229425269020702e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.67668967649282e-07  %  dmg @97.7% prob. survival :  3.923310588393846e-07  %
# Channel 2.1  dmg @50% prob. survival :  2.1206857084499424e-08  %  dmg @97.7% prob. survival :  6.057261311624358e-08  %
# Channel 2.2  dmg @50% prob. survival :  8.693943868695094e-05  %  dmg @97.7% prob. survival :  0.00024832293456499715  %
# Channel 2.3  dmg @50% prob. survival :  1.5063939339941395e-05  %  dmg @97.7% prob. survival :  4.3026751489313694e-05  %
# Channel 2.4  dmg @50% prob. survival :  3.385670281946838e-07  %  dmg @97.7% prob. survival :  9.670404969021512e-07  %
# 23-04-2023_18-34-45-650.csv 7/30
# Channel 1.1  dmg @50% prob. survival :  2.1374966125444954e-08  %  dmg @97.7% prob. survival :  5.001559447901112e-08  %
# Channel 1.2  dmg @50% prob. survival :  3.986375175329134e-09  %  dmg @97.7% prob. survival :  9.327777318576959e-09  %
# Channel 1.3  dmg @50% prob. survival :  4.844469284672043e-07  %  dmg @97.7% prob. survival :  1.133564421978669e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.3569067746152246e-07  %  dmg @97.7% prob. survival :  3.175045919914948e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.9428345607242024e-08  %  dmg @97.7% prob. survival :  5.549269546483977e-08  %
# Channel 2.2  dmg @50% prob. survival :  6.668472385363411e-05  %  dmg @97.7% prob. survival :  0.00019046990144041073  %
# Channel 2.3  dmg @50% prob. survival :  1.2097011705558192e-05  %  dmg @97.7% prob. survival :  3.4552390624560866e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.6068401334148814e-07  %  dmg @97.7% prob. survival :  7.445851982115756e-07  %
# 24-04-2023_00-34-45-687.csv 8/30
# Channel 1.1  dmg @50% prob. survival :  1.9091731632975764e-08  %  dmg @97.7% prob. survival :  4.4673020843771366e-08  %
# Channel 1.2  dmg @50% prob. survival :  3.237856743930992e-09  %  dmg @97.7% prob. survival :  7.576308141734339e-09  %
# Channel 1.3  dmg @50% prob. survival :  4.3445212343442123e-07  %  dmg @97.7% prob. survival :  1.016580849705511e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.209593726051961e-07  %  dmg @97.7% prob. survival :  2.830345972549034e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.425268951987547e-08  %  dmg @97.7% prob. survival :  4.070959900910678e-08  %
# Channel 2.2  dmg @50% prob. survival :  5.869049248144108e-05  %  dmg @97.7% prob. survival :  0.00016763617920896034  %
# Channel 2.3  dmg @50% prob. survival :  1.0855119898074212e-05  %  dmg @97.7% prob. survival :  3.100520625455996e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.2416502027816902e-07  %  dmg @97.7% prob. survival :  6.402769157819213e-07  %
# 24-04-2023_06-34-45-710.csv 9/30
# Channel 1.1  dmg @50% prob. survival :  4.0732953650523115e-06  %  dmg @97.7% prob. survival :  9.531163136159379e-06  %
# Channel 1.2  dmg @50% prob. survival :  2.927368366694787e-08  %  dmg @97.7% prob. survival :  6.849791866803668e-08  %
# Channel 1.3  dmg @50% prob. survival :  5.846225904437758e-07  %  dmg @97.7% prob. survival :  1.3679669121007447e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.616365021649471e-07  %  dmg @97.7% prob. survival :  3.782156050135538e-07  %
# Channel 2.1  dmg @50% prob. survival :  0.000671978652296127  %  dmg @97.7% prob. survival :  0.001919355742611153  %
# Channel 2.2  dmg @50% prob. survival :  0.00010988864917957938  %  dmg @97.7% prob. survival :  0.00031387218794816087  %
# Channel 2.3  dmg @50% prob. survival :  7.799853059920877e-05  %  dmg @97.7% prob. survival :  0.0002227852434139593  %
# Channel 2.4  dmg @50% prob. survival :  3.844470735914746e-05  %  dmg @97.7% prob. survival :  0.00010980865179369584  %
# 24-04-2023_12-34-45-750.csv 10/30
# Channel 1.1  dmg @50% prob. survival :  2.7169337325575914e-06  %  dmg @97.7% prob. survival :  6.357392802235461e-06  %
# Channel 1.2  dmg @50% prob. survival :  4.004764212675847e-09  %  dmg @97.7% prob. survival :  9.370806094828203e-09  %
# Channel 1.3  dmg @50% prob. survival :  5.003131405411368e-07  %  dmg @97.7% prob. survival :  1.1706900026391507e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.3960635269661034e-07  %  dmg @97.7% prob. survival :  3.2666693749037e-07  %
# Channel 2.1  dmg @50% prob. survival :  2.8804291479616426e-08  %  dmg @97.7% prob. survival :  8.227297411060426e-08  %
# Channel 2.2  dmg @50% prob. survival :  6.949504534545818e-05  %  dmg @97.7% prob. survival :  0.00019849695211454982  %
# Channel 2.3  dmg @50% prob. survival :  1.2547688898790622e-05  %  dmg @97.7% prob. survival :  3.583964856934971e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.946948500371657e-07  %  dmg @97.7% prob. survival :  8.417294966200152e-07  %
# 24-04-2023_18-34-45-788.csv 11/30
# Channel 1.1  dmg @50% prob. survival :  1.6957653540231768e-08  %  dmg @97.7% prob. survival :  3.967946044012613e-08  %
# Channel 1.2  dmg @50% prob. survival :  2.9423245719653155e-09  %  dmg @97.7% prob. survival :  6.884788109292022e-09  %
# Channel 1.3  dmg @50% prob. survival :  3.9224481379981384e-07  %  dmg @97.7% prob. survival :  9.178193513086787e-07  %
# Channel 1.4  dmg @50% prob. survival :  1.0925942504958254e-07  %  dmg @97.7% prob. survival :  2.556577196059029e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.3407262538491308e-08  %  dmg @97.7% prob. survival :  3.829482716161692e-08  %
# Channel 2.2  dmg @50% prob. survival :  5.1637753836346705e-05  %  dmg @97.7% prob. survival :  0.00014749161900106696  %
# Channel 2.3  dmg @50% prob. survival :  9.815017123413524e-06  %  dmg @97.7% prob. survival :  2.8034386829521892e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.0217185765840753e-07  %  dmg @97.7% prob. survival :  5.774583979195298e-07  %
# 25-04-2023_00-34-45-811.csv 12/30
# Channel 1.1  dmg @50% prob. survival :  1.7396022749552756e-08  %  dmg @97.7% prob. survival :  4.07052069361338e-08  %
# Channel 1.2  dmg @50% prob. survival :  3.0226289884910077e-09  %  dmg @97.7% prob. survival :  7.072693582837686e-09  %
# Channel 1.3  dmg @50% prob. survival :  4.027898002849705e-07  %  dmg @97.7% prob. survival :  9.424937187314943e-07  %
# Channel 1.4  dmg @50% prob. survival :  1.1254311078808981e-07  %  dmg @97.7% prob. survival :  2.633412636793835e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.532423195623316e-08  %  dmg @97.7% prob. survival :  4.3770218749992284e-08  %
# Channel 2.2  dmg @50% prob. survival :  5.367836653148878e-05  %  dmg @97.7% prob. survival :  0.00015332016977643263  %
# Channel 2.3  dmg @50% prob. survival :  1.0094099047823883e-05  %  dmg @97.7% prob. survival :  2.8831521518913906e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.0754396809921804e-07  %  dmg @97.7% prob. survival :  5.928026220095206e-07  %
# 25-04-2023_06-34-45-846.csv 13/30
# Channel 1.1  dmg @50% prob. survival :  2.710500192977509e-08  %  dmg @97.7% prob. survival :  6.342338869293336e-08  %
# Channel 1.2  dmg @50% prob. survival :  5.043043021541913e-09  %  dmg @97.7% prob. survival :  1.1800289798131364e-08  %
# Channel 1.3  dmg @50% prob. survival :  5.403551874573813e-07  %  dmg @97.7% prob. survival :  1.2643849712728131e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.514765126416014e-07  %  dmg @97.7% prob. survival :  3.544420975877385e-07  %
# Channel 2.1  dmg @50% prob. survival :  2.717977702670057e-08  %  dmg @97.7% prob. survival :  7.763291429105272e-08  %
# Channel 2.2  dmg @50% prob. survival :  7.588412499334569e-05  %  dmg @97.7% prob. survival :  0.0002167459198016709  %
# Channel 2.3  dmg @50% prob. survival :  1.337423984335928e-05  %  dmg @97.7% prob. survival :  3.820050526709765e-05  %
# Channel 2.4  dmg @50% prob. survival :  3.1429752713305e-07  %  dmg @97.7% prob. survival :  8.977201307361669e-07  %
# 25-04-2023_12-34-45-871.csv 14/30
# Channel 1.1  dmg @50% prob. survival :  4.254442524909134e-09  %  dmg @97.7% prob. survival :  9.95503201320586e-09  %
# Channel 1.2  dmg @50% prob. survival :  2.291863050647741e-09  %  dmg @97.7% prob. survival :  5.3627637241547705e-09  %
# Channel 1.3  dmg @50% prob. survival :  8.729741017772061e-08  %  dmg @97.7% prob. survival :  2.0426848121722828e-07  %
# Channel 1.4  dmg @50% prob. survival :  2.751298611603652e-08  %  dmg @97.7% prob. survival :  6.437803683102456e-08  %
# Channel 2.1  dmg @50% prob. survival :  3.871547821176414e-09  %  dmg @97.7% prob. survival :  1.1058204777752247e-08  %
# Channel 2.2  dmg @50% prob. survival :  1.1962783052396029e-05  %  dmg @97.7% prob. survival :  3.4168996694720736e-05  %
# Channel 2.3  dmg @50% prob. survival :  2.110365113518842e-06  %  dmg @97.7% prob. survival :  6.027782855598531e-06  %
# Channel 2.4  dmg @50% prob. survival :  5.0594624351230043e-08  %  dmg @97.7% prob. survival :  1.4451215445902224e-07  %
# 25-04-2023_21-12-38-351.csv 15/30
# Channel 1.1  dmg @50% prob. survival :  1.709375718588258e-08  %  dmg @97.7% prob. survival :  3.999793134239299e-08  %
# Channel 1.2  dmg @50% prob. survival :  2.936616915653172e-09  %  dmg @97.7% prob. survival :  6.871432681177596e-09  %
# Channel 1.3  dmg @50% prob. survival :  3.943132060473005e-07  %  dmg @97.7% prob. survival :  9.226592124466123e-07  %
# Channel 1.4  dmg @50% prob. survival :  1.0968056547173304e-07  %  dmg @97.7% prob. survival :  2.5664315221193516e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.3247718545619921e-08  %  dmg @97.7% prob. survival :  3.783912566295948e-08  %
# Channel 2.2  dmg @50% prob. survival :  5.238112071847245e-05  %  dmg @97.7% prob. survival :  0.00014961487915107768  %
# Channel 2.3  dmg @50% prob. survival :  9.841213598790066e-06  %  dmg @97.7% prob. survival :  2.8109211164013048e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.0524635354120055e-07  %  dmg @97.7% prob. survival :  5.862400032698279e-07  %
# 26-04-2023_03-12-38-390.csv 16/30
# Channel 1.1  dmg @50% prob. survival :  2.2621607037950613e-08  %  dmg @97.7% prob. survival :  5.293262770258192e-08  %
# Channel 1.2  dmg @50% prob. survival :  3.586481068463013e-09  %  dmg @97.7% prob. survival :  8.39205927504291e-09  %
# Channel 1.3  dmg @50% prob. survival :  4.764398219172809e-07  %  dmg @97.7% prob. survival :  1.11482847677055e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.3199006191089353e-07  %  dmg @97.7% prob. survival :  3.0884546777973124e-07  %
# Channel 2.1  dmg @50% prob. survival :  3.9631921682239225e-08  %  dmg @97.7% prob. survival :  1.1319966223871088e-07  %
# Channel 2.2  dmg @50% prob. survival :  6.533111923904868e-05  %  dmg @97.7% prob. survival :  0.00018660363458601414  %
# Channel 2.3  dmg @50% prob. survival :  1.184435929187051e-05  %  dmg @97.7% prob. survival :  3.383074588265959e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.5873001853551975e-07  %  dmg @97.7% prob. survival :  7.390040519370679e-07  %
# 26-04-2023_09-12-38-411.csv 17/30
# Channel 1.1  dmg @50% prob. survival :  7.70414109966345e-09  %  dmg @97.7% prob. survival :  1.80270319395244e-08  %
# Channel 1.2  dmg @50% prob. survival :  1.2048755733017826e-09  %  dmg @97.7% prob. survival :  2.8193058982285727e-09  %
# Channel 1.3  dmg @50% prob. survival :  1.652582077650796e-07  %  dmg @97.7% prob. survival :  3.866900866833445e-07  %
# Channel 1.4  dmg @50% prob. survival :  4.55586331420695e-08  %  dmg @97.7% prob. survival :  1.066033090708929e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.5472688757130358e-08  %  dmg @97.7% prob. survival :  4.4194252180721904e-08  %
# Channel 2.2  dmg @50% prob. survival :  2.3880636770500872e-05  %  dmg @97.7% prob. survival :  6.82096628606516e-05  %
# Channel 2.3  dmg @50% prob. survival :  4.118516932230348e-06  %  dmg @97.7% prob. survival :  1.1763616445115562e-05  %
# Channel 2.4  dmg @50% prob. survival :  1.01503003616767e-07  %  dmg @97.7% prob. survival :  2.899204791973901e-07  %
# 26-04-2023_19-25-13-456.csv 18/30
# Channel 1.1  dmg @50% prob. survival :  2.110573920896117e-08  %  dmg @97.7% prob. survival :  4.9385626496903656e-08  %
# Channel 1.2  dmg @50% prob. survival :  3.5156975892936378e-09  %  dmg @97.7% prob. survival :  8.22643198145223e-09  %
# Channel 1.3  dmg @50% prob. survival :  4.771767845158283e-07  %  dmg @97.7% prob. survival :  1.1165529062858618e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.3275903868082058e-07  %  dmg @97.7% prob. survival :  3.106448077207851e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.535941679715976e-08  %  dmg @97.7% prob. survival :  4.3870716327207416e-08  %
# Channel 2.2  dmg @50% prob. survival :  6.522762459845567e-05  %  dmg @97.7% prob. survival :  0.00018630802544414757  %
# Channel 2.3  dmg @50% prob. survival :  1.1875979693632916e-05  %  dmg @97.7% prob. survival :  3.392106244182655e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.5372422668848204e-07  %  dmg @97.7% prob. survival :  7.247061344435249e-07  %
# 27-04-2023_01-25-13-496.csv 19/30
# Channel 1.1  dmg @50% prob. survival :  7.877644947232143e-08  %  dmg @97.7% prob. survival :  1.8433016118852496e-07  %
# Channel 1.2  dmg @50% prob. survival :  3.220056005816931e-09  %  dmg @97.7% prob. survival :  7.534655935423926e-09  %
# Channel 1.3  dmg @50% prob. survival :  4.2913630242657995e-07  %  dmg @97.7% prob. survival :  1.0041422827253337e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.1914082187744514e-07  %  dmg @97.7% prob. survival :  2.7877934392701584e-07  %
# Channel 2.1  dmg @50% prob. survival :  7.381723935417487e-08  %  dmg @97.7% prob. survival :  2.1084232627617077e-07  %
# Channel 2.2  dmg @50% prob. survival :  5.82684576759444e-05  %  dmg @97.7% prob. survival :  0.0001664307317966849  %
# Channel 2.3  dmg @50% prob. survival :  1.099076886661422e-05  %  dmg @97.7% prob. survival :  3.1392656995526464e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.902618685878172e-07  %  dmg @97.7% prob. survival :  8.290676830750035e-07  %
# 27-04-2023_07-25-13-536.csv 20/30
# Channel 1.1  dmg @50% prob. survival :  1.6240471068973747e-06  %  dmg @97.7% prob. survival :  3.8001314732687457e-06  %
# Channel 1.2  dmg @50% prob. survival :  2.9578383881841453e-09  %  dmg @97.7% prob. survival :  6.921089113760103e-09  %
# Channel 1.3  dmg @50% prob. survival :  2.752925947923934e-07  %  dmg @97.7% prob. survival :  6.441611511052525e-07  %
# Channel 1.4  dmg @50% prob. survival :  7.766941061001256e-08  %  dmg @97.7% prob. survival :  1.817397848348865e-07  %
# Channel 2.1  dmg @50% prob. survival :  2.6362649422661395e-07  %  dmg @97.7% prob. survival :  7.529897324406135e-07  %
# Channel 2.2  dmg @50% prob. survival :  3.9814708689322845e-05  %  dmg @97.7% prob. survival :  0.00011372175217489331  %
# Channel 2.3  dmg @50% prob. survival :  7.2859661877770905e-06  %  dmg @97.7% prob. survival :  2.081072217874033e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.867870711504003e-07  %  dmg @97.7% prob. survival :  8.191427064509766e-07  %
# 27-04-2023_16-36-51-384.csv 21/30
# Channel 1.1  dmg @50% prob. survival :  2.4023366290292975e-08  %  dmg @97.7% prob. survival :  5.62126245882437e-08  %
# Channel 1.2  dmg @50% prob. survival :  4.335335564182174e-09  %  dmg @97.7% prob. survival :  1.0144314813687737e-08  %
# Channel 1.3  dmg @50% prob. survival :  5.354884369092245e-07  %  dmg @97.7% prob. survival :  1.252997190800163e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.495418638127852e-07  %  dmg @97.7% prob. survival :  3.4991518462263745e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.7705594107461432e-08  %  dmg @97.7% prob. survival :  5.0572043636236875e-08  %
# Channel 2.2  dmg @50% prob. survival :  7.484480138583728e-05  %  dmg @97.7% prob. survival :  0.00021377732589220757  %
# Channel 2.3  dmg @50% prob. survival :  1.330956833030658e-05  %  dmg @97.7% prob. survival :  3.801578564909245e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.9329270253940954e-07  %  dmg @97.7% prob. survival :  8.377245779480286e-07  %
# 27-04-2023_22-36-51-405.csv 22/30
# Channel 1.1  dmg @50% prob. survival :  1.6864554522973133e-08  %  dmg @97.7% prob. survival :  3.946161669402147e-08  %
# Channel 1.2  dmg @50% prob. survival :  2.9518109893641405e-09  %  dmg @97.7% prob. survival :  6.9069855154956395e-09  %
# Channel 1.3  dmg @50% prob. survival :  3.8941110143507007e-07  %  dmg @97.7% prob. survival :  9.111887064845862e-07  %
# Channel 1.4  dmg @50% prob. survival :  1.0839006033158943e-07  %  dmg @97.7% prob. survival :  2.5362348044339585e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.367759207918936e-08  %  dmg @97.7% prob. survival :  3.906696263730031e-08  %
# Channel 2.2  dmg @50% prob. survival :  5.112853344037851e-05  %  dmg @97.7% prob. survival :  0.00014603714557708  %
# Channel 2.3  dmg @50% prob. survival :  9.718494634795478e-06  %  dmg @97.7% prob. survival :  2.7758692070190297e-05  %
# Channel 2.4  dmg @50% prob. survival :  1.9712763353625625e-07  %  dmg @97.7% prob. survival :  5.630507072841737e-07  %
# 28-04-2023_04-36-51-427.csv 23/30
# Channel 1.1  dmg @50% prob. survival :  1.866593738049523e-07  %  dmg @97.7% prob. survival :  4.3676698672362187e-07  %
# Channel 1.2  dmg @50% prob. survival :  4.85030341714761e-09  %  dmg @97.7% prob. survival :  1.1349295591315736e-08  %
# Channel 1.3  dmg @50% prob. survival :  5.046255189912714e-07  %  dmg @97.7% prob. survival :  1.180780599767489e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.4169791903199325e-07  %  dmg @97.7% prob. survival :  3.315610240140312e-07  %
# Channel 2.1  dmg @50% prob. survival :  2.2125252129161093e-07  %  dmg @97.7% prob. survival :  6.319580180965209e-07  %
# Channel 2.2  dmg @50% prob. survival :  7.115262014914968e-05  %  dmg @97.7% prob. survival :  0.0002032314413835305  %
# Channel 2.3  dmg @50% prob. survival :  1.3161931375914755e-05  %  dmg @97.7% prob. survival :  3.759409392530307e-05  %
# Channel 2.4  dmg @50% prob. survival :  4.507584060108605e-07  %  dmg @97.7% prob. survival :  1.2874899108038434e-06  %
# 28-04-2023_10-36-51-463.csv 24/30
# Channel 1.1  dmg @50% prob. survival :  8.853557600415454e-07  %  dmg @97.7% prob. survival :  2.0716568346381427e-06  %
# Channel 1.2  dmg @50% prob. survival :  6.010876591649459e-09  %  dmg @97.7% prob. survival :  1.4064937661501812e-08  %
# Channel 1.3  dmg @50% prob. survival :  5.379197951715741e-07  %  dmg @97.7% prob. survival :  1.25868636140136e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.5243600403436091e-07  %  dmg @97.7% prob. survival :  3.566872254688694e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.6776395297247423e-06  %  dmg @97.7% prob. survival :  4.791799641856081e-06  %
# Channel 2.2  dmg @50% prob. survival :  8.010285657822621e-05  %  dmg @97.7% prob. survival :  0.00022879577684148112  %
# Channel 2.3  dmg @50% prob. survival :  1.5480334435335187e-05  %  dmg @97.7% prob. survival :  4.421609033930241e-05  %
# Channel 2.4  dmg @50% prob. survival :  1.1098386986467013e-06  %  dmg @97.7% prob. survival :  3.1700043927585404e-06  %
# 28-04-2023_16-36-51-503.csv 25/30
# Channel 1.1  dmg @50% prob. survival :  2.4124830191459937e-08  %  dmg @97.7% prob. survival :  5.645004144800285e-08  %
# Channel 1.2  dmg @50% prob. survival :  3.9130138944830605e-09  %  dmg @97.7% prob. survival :  9.156118189307882e-09  %
# Channel 1.3  dmg @50% prob. survival :  5.254527128473197e-07  %  dmg @97.7% prob. survival :  1.2295144539370048e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.5265582322411833e-07  %  dmg @97.7% prob. survival :  3.572015835917237e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.701582325967308e-08  %  dmg @97.7% prob. survival :  4.860186849263246e-08  %
# Channel 2.2  dmg @50% prob. survival :  7.61126784078046e-05  %  dmg @97.7% prob. survival :  0.00021739873117750626  %
# Channel 2.3  dmg @50% prob. survival :  1.3487502965546051e-05  %  dmg @97.7% prob. survival :  3.8524015877523145e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.920338205322887e-07  %  dmg @97.7% prob. survival :  8.341288648976524e-07  %
# 28-04-2023_22-36-51-527.csv 26/30
# Channel 1.1  dmg @50% prob. survival :  1.7183679367732896e-08  %  dmg @97.7% prob. survival :  4.02083415650697e-08  %
# Channel 1.2  dmg @50% prob. survival :  2.928738447056387e-09  %  dmg @97.7% prob. survival :  6.852997737789516e-09  %
# Channel 1.3  dmg @50% prob. survival :  3.8490346004109594e-07  %  dmg @97.7% prob. survival :  9.006412107507963e-07  %
# Channel 1.4  dmg @50% prob. survival :  1.1249596408778395e-07  %  dmg @97.7% prob. survival :  2.632309444288253e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.3555641040880456e-08  %  dmg @97.7% prob. survival :  3.8718636950320476e-08  %
# Channel 2.2  dmg @50% prob. survival :  5.254587454517181e-05  %  dmg @97.7% prob. survival :  0.0001500854613672072  %
# Channel 2.3  dmg @50% prob. survival :  9.943804023382255e-06  %  dmg @97.7% prob. survival :  2.8402237616422862e-05  %
# Channel 2.4  dmg @50% prob. survival :  1.9879752182985368e-07  %  dmg @97.7% prob. survival :  5.678203672649791e-07  %
# 29-04-2023_04-36-51-565.csv 27/30
# Channel 1.1  dmg @50% prob. survival :  3.57855342703931e-08  %  dmg @97.7% prob. survival :  8.373509271442266e-08  %
# Channel 1.2  dmg @50% prob. survival :  7.887105065038429e-09  %  dmg @97.7% prob. survival :  1.845515198625763e-08  %
# Channel 1.3  dmg @50% prob. survival :  4.78630835498706e-07  %  dmg @97.7% prob. survival :  1.1199552613531728e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.4341286253621555e-07  %  dmg @97.7% prob. survival :  3.3557384529093846e-07  %
# Channel 2.1  dmg @50% prob. survival :  2.864258644703702e-07  %  dmg @97.7% prob. survival :  8.181110008849271e-07  %
# Channel 2.2  dmg @50% prob. survival :  6.710825501273147e-05  %  dmg @97.7% prob. survival :  0.00019167962284988134  %
# Channel 2.3  dmg @50% prob. survival :  1.2490397536690794e-05  %  dmg @97.7% prob. survival :  3.5676008691092776e-05  %
# Channel 2.4  dmg @50% prob. survival :  4.81750411189527e-07  %  dmg @97.7% prob. survival :  1.3760115965916614e-06  %
# 29-04-2023_10-36-51-586.csv 28/30
# Channel 1.1  dmg @50% prob. survival :  3.796921217998954e-08  %  dmg @97.7% prob. survival :  8.884471245176504e-08  %
# Channel 1.2  dmg @50% prob. survival :  4.868252701465137e-09  %  dmg @97.7% prob. survival :  1.1391295383051378e-08  %
# Channel 1.3  dmg @50% prob. survival :  5.699674042060688e-07  %  dmg @97.7% prob. survival :  1.3336750284282189e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.6458006035786593e-07  %  dmg @97.7% prob. survival :  3.8510327969047374e-07  %
# Channel 2.1  dmg @50% prob. survival :  7.13754309394799e-07  %  dmg @97.7% prob. survival :  2.03867850246325e-06  %
# Channel 2.2  dmg @50% prob. survival :  8.50600835942583e-05  %  dmg @97.7% prob. survival :  0.00024295497982828224  %
# Channel 2.3  dmg @50% prob. survival :  1.5248351911380165e-05  %  dmg @97.7% prob. survival :  4.355348448416496e-05  %
# Channel 2.4  dmg @50% prob. survival :  5.601031620410153e-07  %  dmg @97.7% prob. survival :  1.5998085904132989e-06  %
# 29-04-2023_16-36-51-623.csv 29/30
# Channel 1.1  dmg @50% prob. survival :  1.959528433609513e-08  %  dmg @97.7% prob. survival :  4.585129114605959e-08  %
# Channel 1.2  dmg @50% prob. survival :  3.270613027932002e-09  %  dmg @97.7% prob. survival :  7.652955047634224e-09  %
# Channel 1.3  dmg @50% prob. survival :  4.315704999105239e-07  %  dmg @97.7% prob. survival :  1.0098380968626221e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.2665576389681244e-07  %  dmg @97.7% prob. survival :  2.9636366618358407e-07  %
# Channel 2.1  dmg @50% prob. survival :  2.0220834419105923e-08  %  dmg @97.7% prob. survival :  5.775626134868264e-08  %
# Channel 2.2  dmg @50% prob. survival :  6.093076155307144e-05  %  dmg @97.7% prob. survival :  0.00017403500347655814  %
# Channel 2.3  dmg @50% prob. survival :  1.120837265153106e-05  %  dmg @97.7% prob. survival :  3.201419321958649e-05  %
# Channel 2.4  dmg @50% prob. survival :  2.381839699656928e-07  %  dmg @97.7% prob. survival :  6.803188895799997e-07  %
# complete

# %%
#POST PROCESSING OF DATASET
dataset = []
channelList = ['Channel 1.1', 'Channel 1.2','Channel 1.3','Channel 1.4','Channel 2.1','Channel 2.2','Channel 2.3','Channel 2.4']
damage97 =[]
damage50 =[]
for j in range(len(Channels)):
    dataset.append({
        'name' : Channels[j],
        '50 Damage' : 0 ,
        '97 Damage':0,
        'Stress Range':[],
        'Maximum Stress Range':0,
    })  
for i in range(len(JSONStructure)):#Loop throguh the JSON object , and view each file name.
    for j in range(len(JSONStructure[i]['File']['Channel Data'])): #Loop through the channel data to view each channel dataset.      
        ChannelName = JSONStructure[i]['File']['Channel Data'][j]['Channel Name'] # define a variable to channelname.
        for j in range(len(Channels)):#Loop through the summary data array and find the place to put the data.
            if ChannelName == dataset[j]['name']:#Check that the right channel has been found.
                dataset[j]['50 Damage'] = dataset[j]['50 Damage'] + JSONStructure[i]['File']['Channel Data'][j]['50 Damage']#Add the data sets together into the storage array.
                dataset[j]['97 Damage'] = dataset[j]['97 Damage'] + JSONStructure[i]['File']['Channel Data'][j]['97 Damage']#Add the data sets together into the storage array.
                dataset[j]['Stress Range'].append(JSONStructure[i]['File']['Channel Data'][j]['Maximum Stress'] -JSONStructure[i]['File']['Channel Data'][j]['Minimum Stress']) # Calculate stress range 
                damage50.append(dataset[j]['50 Damage'])
                damage97.append(dataset[j]['97 Damage'])
#print(dataset)                
for i in range(len(dataset)):
    dataset[i]['Maximum Stress Range']  = max(dataset[i]['Stress Range']) 
    dataset[i].pop('Stress Range')

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot 50 Damage
ax1.set_title('50 Damage')
ax1.set_xlabel('Channel')
ax1.set_ylabel('Damage')
for i, data in enumerate(dataset):
    name = data["name"]
    damage_50 = data["50 Damage"]
    ax1.bar(i, damage_50, label=name)
ax1.legend()

# Plot 97 Damage
ax2.set_title('97 Damage')
ax2.set_xlabel('Channel')
ax2.set_ylabel('Damage')
for i, data in enumerate(dataset):
    name = data["name"]
    damage_97 = data["97 Damage"]
    ax2.bar(i, damage_97, label=name)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
#This cell is used to visually compare the local and cloud servers.
import pymongo
import datetime
from pymongo import MongoClient
import os
import pprint
import pandas as pd
import certifi

# Environment variable for MongoDB collection
COLLECTION_PROCCESSED_DATA = os.getenv('COLLECTION_PROCCESSED_DATA')

# Connect to the remote MongoDB database
user = os.getenv('MYSQL_USER')
password = os.getenv('MYSQL_PASSWORD')
remote_conn_text = f'mongodb+srv://{user}:{password}@entangelment.2vytk.mongodb.net/?retryWrites=true&w=majority'
remote_client = MongoClient(remote_conn_text, tlsCAFile=certifi.where())
remote_db = remote_client.entangelment
remote_collection = remote_db[COLLECTION_PROCCESSED_DATA]

# Fetch last 10 entries from the remote MongoDB
remote_last_entries = remote_collection.find().sort("_id", pymongo.DESCENDING).limit(10)

# Connect to the local MongoDB database
local_conn_text = 'mongodb://localhost:27017'
local_client = MongoClient(local_conn_text)
local_db = local_client.entangelment
local_collection = local_db[COLLECTION_PROCCESSED_DATA]

# Fetch last 10 entries from the local MongoDB
local_last_entries = local_collection.find().sort("_id", pymongo.DESCENDING).limit(10)

# Print "description" data from the remote database
print("Description from the Remote DB:")
for entry in remote_last_entries:
    print(entry.get('Description', "N/A"))

# Print "description" data from the local database
print("\nDescription from the Local DB:")
for entry in local_last_entries:
    print(entry.get('Description', "N/A"))
# Out:
# Description from the Remote DB:
# C:/Users/jdavi/Desktop/Fines April/e/
# C:/Users/jdavi/Desktop/Fines April/d/
# C:/Users/jdavi/Desktop/Fines April/c/
# C:/Users/jdavi/Desktop/Fines April/b/
# C:/Users/jdavi/Desktop/Fines April/a/
# C:/Users/MY PC/Desktop/Fines/
# D:/New folder/FINES/FINES - January 2023/06/e/
# D:/New folder/FINES/FINES - January 2023/06/d/
# D:/New folder/FINES/FINES - January 2023/06/c/
# D:/New folder/FINES/FINES - January 2023/06/b/
#
# Description from the Local DB:
# C:/Users/MY PC/Desktop/Fines/
# D:/New folder/FINES/FINES - January 2023/06/e/
# D:/New folder/FINES/FINES - January 2023/06/d/
# D:/New folder/FINES/FINES - January 2023/06/c/
# D:/New folder/FINES/FINES - January 2023/06/b/
# D:/New folder/FINES/FINES - January 2023/06/a/
# D:/New folder/FINES/FINES - January 2023/05/k/
# D:/New folder/FINES/FINES - January 2023/05/j/
# D:/New folder/FINES/FINES - January 2023/05/i/
# D:/New folder/FINES/FINES - January 2023/05/h/

# %%
import pymongo #import the pymongo pip
import datetime
#mongodb://heroku_6x00zflw:muikokfevp1h13d5pu0ph74p21@ds161109.mlab.com:61109/heroku_6x00zflw
from pymongo import MongoClient
user = os.getenv('MYSQL_USER')
userPC = os.environ['COMPUTERNAME'] # WORK ONLY ON WINDOWS
password = os.getenv('MYSQL_PASSWORD')
host = os.getenv('MYSQL_HOST')
COLLECTION_PROCCESSED_DATA = os.getenv('COLLECTION_PROCCESSED_DATA')
conn_text = 'mongodb+srv://{}:{}@{}/?retryWrites=true&w=majority'.format(user,password,host)
client = MongoClient(conn_text, tlsCAFile=certifi.where())
db = client.entangelment
collection = db[COLLECTION_PROCCESSED_DATA]
post = {"author": userPC,
        "timestamp": datetime.datetime.utcnow(),
        "Description":path,
        'data':JSONStructure,
        'summary':dataset,
        
       }
post_id = collection.insert_one(post)
print('complete ' + path)
# Out:
# complete C:/Users/jdavi/Desktop/Fines April/e/

# %%
#Notes
# Should there be issues with the array struture above, here is the structure.:
example = {
  "File Name": [
    "03-05-2020_02-37-05-588.csv"
  ],
  "Channel": [
    "Channel 1.1",
    "Channel 1.2",
    "Channel 1.3",
    "Channel 1.4",
    "Channel 2.1",
    "Channel 2.2",
    "Channel 2.3",
    "Channel 2.4"
  ]
}
