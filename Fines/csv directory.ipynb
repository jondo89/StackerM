# %%
#######################################
########  READ THE CSV FILES  ########
#####################################

############################################
########### Importing Modules ##############
############################################
import matplotlib.pyplot as plt
import numpy as np
from math import pi
import scipy.fftpack as sf
import scipy.signal as sig
import rainflow
import pandas
import glob # module for reading files from a directory
import os # module for getting only the filename not the whole path
from datetime import datetime

path = r'C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\\' # Specify the folder with CSV files
    
RawData = pandas.DataFrame() # Initialize an empty dataframe 

names = [os.path.basename(x) for x in glob.glob(path+"*.csv", recursive=True)]

datelist = []


for file_name in glob.glob(path+'*.csv', recursive=True):
    print(file_name)
    nameFile = os.path.basename(file_name)#get the file name of the extract only.
    x = pandas.read_csv(file_name, delimiter=';',low_memory=False)#read in each CSV file
    #Extract the start and end times on each CSV file
    startTime= str(x.iloc[[0]]['Time'].values[0]) # string extract of start and end times for CSV
    EndTime= str(x.iloc[[-5]]['Time'].values[0]) # string extract of start and end times for CSV
    #print(startTime)
    #print(EndTime)
    
    #require string test for failed CSV files here. hence the -5
    
    #datetime_object = str(date[0:10]).replace("-", " ")
    #print(datetime_object)
    dateObject = str(startTime[0:10]).replace("-", " ")
    timeObject = str(startTime[11:19]).replace("-", " ")
    total = dateObject+' '+timeObject
    dateObject = datetime.strptime(total, '%d %m %Y %H %M %S')
    startTimeStr = str(dateObject)
    startTime = dateObject
    
    dateObject = str(EndTime[0:10]).replace("-", " ")
    timeObject = str(EndTime[11:19]).replace("-", " ")
    total = dateObject+' '+timeObject
    dateObject = datetime.strptime(total, '%d %m %Y %H %M %S')
    EndTimeStr = str(dateObject)
    EndTime = dateObject
    
    
    duration = EndTime - startTime
    print(duration)
    #print('this is the duration : ', duration)
    
    #RawData = pandas.concat([RawData.reset_index(drop=True),x.reset_index(drop=True)], axis= 0, sort=False)
    #print(RawData)
    
    datelist.append({
        "filename":nameFile,
        "startdate":startTimeStr,
        "enddate":EndTimeStr,
        "duration":str(duration),
    })

##ChannelList=['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4']

#print(datelist['duration'])
# Out:
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\01-08-2020_00-44-16-812.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\01-08-2020_06-44-16-849.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\01-08-2020_12-44-16-889.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\01-08-2020_18-44-16-927.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\02-08-2020_00-44-16-948.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\02-08-2020_06-44-16-972.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\02-08-2020_12-44-17-008.csv
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\27-08-2020_16-47-42-765.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\27-08-2020_22-47-42-789.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\28-08-2020_04-47-42-826.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\28-08-2020_10-47-42-847.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\28-08-2020_16-47-42-887.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\28-08-2020_22-47-42-925.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\29-08-2020_04-47-42-948.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\29-08-2020_10-47-42-984.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\29-08-2020_16-47-43-008.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\29-08-2020_22-47-43-048.csv
# 5:59:59
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\30-08-2020_04-47-43-085.csv
# 5:59:59
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\30-08-2020_10-47-43-106.csv
# 5:59:59
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\30-08-2020_16-47-43-127.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\30-08-2020_22-47-43-148.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\31-08-2020_04-47-43-169.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\31-08-2020_10-47-43-207.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\31-08-2020_16-47-43-227.csv
# 6:00:00
# C:\Users\Karabo Mogotlane\Desktop\StackerM\Fines\CSV\31-08-2020_22-47-43-265.csv
# 6:00:00

# %%
datelist[3]
# Out:
# {'filename': '01-08-2020_18-44-16-927.csv',
#  'startdate': '2020-08-01 18:44:16',
#  'enddate': '2020-08-02 00:44:16',
#  'duration': '6:00:00'}

# %%
##############################################
########  CONNECT TO REMOTE MONGODB  ########
############################################

import pymongo #import the pymongo pip
import datetime
#mongodb://heroku_6x00zflw:muikokfevp1h13d5pu0ph74p21@ds161109.mlab.com:61109/heroku_6x00zflw
from pymongo import MongoClient
client = MongoClient('mongodb://kmogotlane:QLtbukKU-47m2Psb@ds251284.mlab.com:51284/entangelment?retryWrites=false')
db = client.entangelment
collection = db['entangelment']
post = {
        "author": "jon",
        "date": datelist,
        "timestamp": datetime.datetime.utcnow()
       }
post_id = collection.insert_one(post)

# This can be pushed without any code modification
