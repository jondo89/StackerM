# %%
#----------------------------------------------------------------------------------
#--------------   GET THE LIST OF CSV FILES FROM MONGO WEB   ----------------------
#---------------------------------------------------------------------------------
import pymongo #import the pymongo pip
import datetime
#mongodb://heroku_6x00zflw:muikokfevp1h13d5pu0ph74p21@ds161109.mlab.com:61109/heroku_6x00zflw
from pymongo import MongoClient
client = MongoClient('mongodb://heroku_6x00zflw:muikokfevp1h13d5pu0ph74p21@ds161109.mlab.com:61109/heroku_6x00zflw?retryWrites=false')
db = client.test_database
db = client['heroku_6x00zflw']
collection = db['entangelmentlumpy']
#dataset = collection.find_one()#find remote data on mongodb server.
dataset = collection.find_one( sort=[( '_id', pymongo.DESCENDING )])
#dataset
#---------------------------------------------------------------------------
#--------------   PRINT THE LIST BOX FOR PROCESSING   ----------------------
#---------------------------------------------------------------------------
import ipywidgets as widgets
mainarray = {} #initialize the main array
filenamelist = [] #initialize the csv array of filenames

for i in dataset['date']: 
    dataloop = i['filename']
    #print(dataloop)     
    filenamelist.append(dataloop)


class SelectMultipleInteract(widgets.HBox):

    def __init__(self):
        self.W1 = widgets.SelectMultiple(
            options=filenamelist,
            rows=8,
            description='File Name',
            disabled=False
        )

        self.W2 = widgets.SelectMultiple(
            options=['Channel 1.1', 'Channel 1.2','Channel 1.3','Channel 1.4','Channel 2.1','Channel 2.2','Channel 2.3','Channel 2.4'],
            rows=8,
            description='Channel',
            disabled=False
        )

        self.selectors = [self.W1, self.W2]
        super().__init__(children=self.selectors)
        self._set_observes()

    def _set_observes(self):
        for widg in self.selectors:
            widg.observe(self._observed_function, names='value')

    def _observed_function(self, widg):
        for widg in self.selectors:
            #print(widg.description)
            #print(widg.get_interact_value())
            mainarray[widg.description] = widg.get_interact_value()
            
SelectMultipleInteract()
# Out:
# SelectMultipleInteract(children=(SelectMultiple(description='File Name', options=('01-03-2020_03-02-28-059.csv…

# %%
#------------------------------------------------------------
#--------------   MAIN ARRAY CREATED   ----------------------
#------------------------------------------------------------
mainarray
path = r'C:\Users\Karabo Mogotlane\Desktop\StackerM\Lumpy\CSV\\'
Files =[]
JSONStructure = []
Channels = [] 
tempVar= []
tempVar2= []

#######################################
########  READ THE CSV FILES  ########
#####################################

############################################
########### Importing Modules ##############
############################################

import numpy as np
import pandas
import glob # module for reading files from a directory
import os # module for getting only the filename not the whole path
from datetime import datetime

path = r'C:\Users\Karabo Mogotlane\Desktop\StackerM\Lumpy\CSV\\' # Specify the folder with CSV files
    
for i in range(len(mainarray['File Name'])):
    
    Files.append(path+mainarray['File Name'][i])
    x = pandas.read_csv(path+mainarray['File Name'][i], delimiter=';',low_memory=False)#read in each CSV file
    #Extract the start and end times on each CSV file
    startTime= str(x.iloc[[0]]['Time'].values[0]) # string extract of start and end times for CSV
    EndTime= str(x.iloc[[-5]]['Time'].values[0]) # string extract of start and end times for CSV
    dateObject = str(startTime[0:10]).replace("-", " ")
    timeObject = str(startTime[11:19]).replace("-", " ")
    total = dateObject+' '+timeObject
    dateObject = datetime.strptime(total, '%d %m %Y %H %M %S')
    startTimeStr = str(dateObject)
    startTime = dateObject
    
    dateObject = str(EndTime[0:10]).replace("-", " ")
    timeObject = str(EndTime[11:19]).replace("-", " ")
    total = dateObject+' '+timeObject
    dateObject = datetime.strptime(total, '%d %m %Y %H %M %S')
    EndTimeStr = str(dateObject)
    EndTime = dateObject
    
    
    duration = EndTime - startTime
    
    tempVarArray= []
    for Channel in mainarray['Channel']:
        Channel = Channel.strip('\"')
        Channels.append(Channel)        
        tempVar =   { 'Channel Name':Channel,
                    
                    }
        tempVarArray.append(tempVar)
    tempVar2 = {
        "File" : {
                'file name':mainarray['File Name'][i],
                "Duration": str(duration),
                "Channel Data" : tempVarArray,
                
                }
    }               
    JSONStructure.append(tempVar2)

print(JSONStructure[0])
Channels = list(dict.fromkeys(Channels)) # remove duplicates inside the channel list
#print(mainarray['Channel'])
#print(Channels)
# Out:
# {'File': {'file name': '01-03-2020_03-02-28-059.csv', 'Duration': '0:17:12', 'Channel Data': [{'Channel Name': 'Channel 1.1'}, {'Channel Name': 'Channel 1.2'}, {'Channel Name': 'Channel 1.3'}]}}

# %%
############################################################################################################
######################################### Importing Modules ################################################
############################################################################################################

import matplotlib.pyplot as plt
import numpy as np
from math import pi
import scipy.fftpack as sf
import scipy.signal as sig
import rainflow
import pandas
import glob # module for reading files from a directory
import os # module for getting only the filename not the whole path
from pylab import*
import json
########################################################################################################
##################################### Create a Low Path Filter #########################################
########################################################################################################

Fs = 50;
o = 8;
fc = np.array([2]) #Cut Off Frequncy
wc = 2*fc/Fs;
[b,a] = sig.butter(o, wc, btype = 'lowpass')
# filter response
[W,h] = sig.freqz(b,a, worN=1024)
W = Fs* W/(2*pi)

# %%
#########################################################################################################
############   generate a matrix of seq, x,y ; sequence, time and stresses    ##########################
############               Apply correction factor per weld class             #########################
#########################################################################################################
# n = GetChannelData(Channel)[1]
# y = GetChannelData(Channel)[0]

def GetChannelData(Channel):
    #print('Begin Channel, GetChannelData')
    ChannelData =[]
    yZ=Channel
    TimeLength=len(yZ)
    seq=[round(x,1) for x in range(1, TimeLength+1)]
    x1= [round(x*0.02,3) for x in range(0, TimeLength)]
    data={'seq':seq,'x':x1,'y':yZ}
    data = pandas.DataFrame(data, columns=['seq','x', 'y'])
    data.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
    x = data.x.tolist()
    y = data.y.tolist()
    Corr1 = 0.1840265*0.207 # Channel 1.1 to 1.4 weld class W
    Corr2 = 0.4784689*0.207 # Channel 2.1 to 2.4 weld class F2
    Slot1=['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4'] 
    if Channel.name in Slot1:
        y = [float(p)*Corr1 for p in y if str(p) !='nan']
        ChannelData.append(y)
    else:
        y = [float(p)*Corr2 for p in y if str(p) !='nan']
        ChannelData.append(y)
    l = np.size(y)
    n = np.arange(0,l,1)
    ChannelData.append(n)
   # print('End of function, GetChannelData')
    return ChannelData
############################################################################################################
############################### Graphing / plotting function ###############################################
############################################################################################################
def myplot(x,y,Title, xlabel, ylabel):    
    #print('Begin, MyPlot')
    fig =plt.figure()
    plt.plot( x, y)
    #x = plot(t,x)
    fig.savefig('plot.png')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(Title)
    plt.grid(True)
    #print('End, MyPlot')
    return fig
###############################################################################################################
############################## Signal Characteristics and Fourier#############################################
##############################################################################################################
def FourierTransform(y):
   # print('Begin, FFT')
    FourierResults = []
    Fs = 50; #Sampling Frequency
    l = np.size(y)
    n = np.arange(0,l,1)
    # Take spectral analysis
    # calculating the fft
    X_f = abs(sf.fft(yP))
    l = np.size(y)
    fr = (Fs/2)*np.linspace(0,1,l//2)
    FourierResults.append(fr)
    xl_m = (2/l)*abs(X_f[0:np.size(fr)]);
    FourierResults.append(xl_m)
    Db = 20*np.log10(xl_m)
    FourierResults.append(Db)
    #print('End, FFT')
    return FourierResults
#####################################################################################################################
############## Plotting Raw Data, Spectrum, and Filtired Signal per channel #########################################
#####################################################################################################################

def PlotSlot1(Channel):
   # print('Begin, PlotSlot1')
    Slot1=['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4'] 
    for Channel in Slot1:
        #Plot Raw data Stress // by calling functions
        myplot( GetChannelData(Channel)[1], GetChannelData(Channel)[0], Channel.name+' Raw Data', 'Time', 'Stress (MPa)')
        #Plot the spectrum
        myplot(FourierTransform(GetChannelData(Channel)[1])[0],FourierTransform(GetChannelData(Channel)[1])[2] , Channel.name +' Spectrum','Frequency','Amplitute')
        #Filtered Signal
        x_filt = sig.lfilter(b,a, GetChannelData(Channel)[0])
        myplot(GetChannelData(Channel)[1],x_filt, Channel+' Filtered Signal', 'Time', 'Stress (MPa)')    
   # print('End, PlotSlot1')
    plt.show()

##########################################################################################################
################################# Package The Filtered Signal  ###########################################
##########################################################################################################
def FilteredSignal(Channel):
    #print('Begin, FilteredSignal')
    
    #x_filt = sig.filtfilt(b,a, GetChannelData(Channel)[0]) # forward and backward
    x_filt =  GetChannelData(Channel)[0]
    #x_filt = sig.lfilter(b,a, GetChannelData(Channel)[0]) # Forward only
    #fc = 2  # Cut-off frequency of the filter
   # w = fc / (fs / 2) # Normalize the frequency
    b, a = sig.butter(8, w, 'low')
    #output = signal.filtfilt(b, a, signalc)
    #_filt = sig.lfilter(b, a, GetChannelData(Channel)[0])
    TimeLength=len(x_filt)
    seq=[round(x,1) for x in range(1, TimeLength+1)]
    x2= [round(x*0.02,3) for x in range(0, TimeLength)]
    Filtered={'seq':seq,'xf':x2,'yf':x_filt}
    Filtered= pandas.DataFrame(Filtered, columns=['seq','xf', 'yf'])
    #Filtered = Filtered.drop(Filtered.head(100).index)
    plt.plot( Filtered['xf'], Filtered['yf'], label=Channel.name)
    
    #print(Filtered.describe())
    #print('End, FilteredSignal')
    return Filtered
########################################################################################################################
##########################################################################################################################
############################################ RainFlow Counting ###########################################################
##########################################################################################################################

#Rainflow Counting
#FilteredSignal(Channel)
#RainFlow()[0] The CSV File
#RainFlow()[1] The damages 

def RainFlow(Filtered, Channel):
    #print(Channel)
    print('Begin, RainFlow')
    RainFlow_Results =[] #Initialize an empty list to store the results of Rainflow Algorithm
    x = Filtered.xf.tolist()
    y = round(Filtered['yf'],3).tolist()
    # Rainflow Count Algorithm
    # Function count_cycles returns a sorted list of the load ranges and the corresponding number of cycles
    # 3 decimal digits is used for precision
    val = rainflow.count_cycles(y, 3)
    #print(Channel)
    #print(val)
    #print("Output (Range,Cycles) = ", val)
    # Mean, Range , Cycle Count list use to store each point in 3-Dimension
    mn = []
    rg = []
    z = []
    #val = []
    # Detailed output, like cycle lows, highs or means, use extract_cycles
    for rng, mean, count, i_start, i_end in rainflow.extract_cycles(y): 
        mn.append(mean)
        rg.append(rg)
        #val.append(count)
        
   # for low, high, mult in rainflow.extract_cycles(y, True, True):
       # mean = 0.5 * (high + low)
        # Append Of The mean List
       # mn.append(mean)
        #rng = high - low
        # Append Of The Range List
        #rg.append(rng)
    # Create a Data Frame using panda to better manage the list of range and cycle counts
    # generated from rainflow.count_cycles function
    d1 = {'range_cycles': val}
    df2 = pandas.DataFrame(d1)
    
    df2[['range', 'cycles']] = pandas.DataFrame(df2.range_cycles.values.tolist(), index=df2.index)
    #print('df2',df2)
    
    #print(df2['cycles'].sum())
    
    
    ###########################################################################
    ########################### Compute the damage ############################
    ###########################################################################
    # 50% probability of failure
    # LogCo=12.6007, d = 0, m = 3, delta = 0.2095 weld class D
    damage1 = 0 #50 % damage
    damage2 = 0 # 97.7 % damage
    Slot1=['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4'] 
    if Channel in Slot1 :
        for num1, num2 in zip(df2['range'], df2['cycles']):
            Nfw=10**(11.5662-3*np.log10(num1))
            Ni = (num2/Nfw)*100
            damage1=damage1+Ni
    else:
         for num1, num2 in zip(df2['range'], df2['cycles']):
            Nfw=10**(12.0900-3*np.log10(num1))
            Ni = (num2/Nfw)*100
            damage1=damage1+Ni
    print('The damage is',damage1,'%,',' Based on 50 % probability of survival') 
    #97.7% probability of survival
    if Channel in Slot1 :
        for num1, num2 in zip(df2['range'], df2['cycles']):
            Nfw=10**(11.5662-0.1846*2-3*np.log10(num1))
            #print(Nfw)
            Ni = (num2/Nfw)*100
            #print(Ni)
            damage2=damage2+Ni
    else:
        for num1, num2 in zip(df2['range'], df2['cycles']):
            Nfw=10**(12.090-0.2279*2-3*np.log10(num1))
            #print(Nfw)
            Ni = (num2/Nfw)*100
            #print(Ni)
            damage2=damage2+Ni
    print('The damage is',damage2,'%,',' Based on 97.7 % probability of survival') 
    #Append the damages 
    RainFlow_Results.append(damage1)
    RainFlow_Results.append(damage2)
    return RainFlow_Results

#####################################################################################################
################################  Running the Script Section ########################################
############################### Reading CSV Files From Folder #######################################
#####################################################################################################

path = r'C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\' # Specify the folder with CSV files
Files =[] # empty array to store Files
FileResults = [] #
ChannelData = []
for i in range(len(mainarray['File Name'])):
    Files.append(mainarray['File Name'][i])
    
RawData = pandas.DataFrame() # Initialize an empty dataframe 
for file_nameShort in Files:
    file_name = path+file_nameShort
    FileResults.append(file_name) # store the filename
    print(file_name)
    x = pandas.read_csv(file_name, delimiter=';',low_memory=False)
    #x = x.drop(x.head(5).index)
    x = x.drop(x.tail(3).index)
    # Calling the function on each Filename
    #print(Channels)
    for Channel in Channels:
        #print(Channel)
        FileResults.append(Channel) # store Channel name
        ab1 = FilteredSignal(x[Channel])
        ab2 = RainFlow(ab1,Channel)
        FileResults.append(ab2[0])  #damage 50 %
        FileResults.append(ab2[1])  #damage 97.7%

        #RainFlow(FilteredSignal(x[Channel]), x[Channel])[1]

        FileResults.append(ab1.min()[2]) # min
        FileResults.append(ab1.max()[2]) # max
        
        #print(Channel)
        #print(file_name)
        
        #Assign outputs to JSONStructure
        #1. Find the File name in the JSONStructure we are looking for.
        for i in JSONStructure:
            #print(i['File']['file name'] ,'gggggggggggggggggggggg', file_nameShort,'sdsdsdsdsdsdsd')
            if i['File']['file name'] == file_nameShort:
                #2. Find the Channel Name We are looking for in the JSONStructure.
                for j in i['File']['Channel Data']:
                    if j['Channel Name'] == Channel:
                        #3. Assign the Data
                        #print(j['Channel Name'] ,'gggggggggggggg',Channel,'fgffgfgfgfgfgfgfg')
                        j['50 Damage'] = ab2[0]
                        j['97 Damage'] = ab2[1]
                        j['Minimum Stress']=ab1.min()[2]
                        j['Maximum Stress']=ab1.max()[2]          
        #RainFlow(FilteredSignal(x[Channel]), x[Channel]       
    RawData = pandas.concat([RawData.reset_index(drop=True),x.reset_index(drop=True)], axis= 0, sort=False)
RawData = pandas.DataFrame(RawData, columns=['Channel 1.1', 'Channel 1.2','Channel 1.3','Channel 1.4','Channel 2.1','Channel 2.2','Channel 2.3','Channel 2.4'])
ChannelList=['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4']
RawData.to_csv('TestData5.csv', index=True, header=True)
#print(RawData)
for Channel in Channels:
        #print(Channel)
        #FileResults.append(Channel) # store Channel name
        ab1 = FilteredSignal(RawData[Channel])
        #print(Channel)
        ab2 = RainFlow(ab1,Channel)

############################################# Pactkage the file to be posted ################################
#LC =len(Channels)
#FilePackage = [FileResults[i:i+5*LC+1] for i in range(0, len(FileResults), 5*LC+1)]
##########################################################################################################
################################# Running the Combined Files #############################################
##########################################################################################################
# Out:
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\01-05-2020_02-37-05-347.csv
# Begin, RainFlow
# The damage is 7.062187454322727e-08 %,  Based on 50 % probability of survival
# The damage is 1.6524915257270364e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.1006310949297266e-08 %,  Based on 50 % probability of survival
# The damage is 4.915297286431182e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.0127201092296508e-06 %,  Based on 50 % probability of survival
# The damage is 4.70959309091486e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.5840445459947929e-06 %,  Based on 50 % probability of survival
# The damage is 3.7065288985331196e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.514505402849985e-07 %,  Based on 50 % probability of survival
# The damage is 2.7176042751753985e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.00016461629245520334 %,  Based on 50 % probability of survival
# The damage is 0.0004701893805281574 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.7905489353072662e-05 %,  Based on 50 % probability of survival
# The damage is 7.970574817694249e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0762139135146906e-06 %,  Based on 50 % probability of survival
# The damage is 3.0739627637340924e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\01-05-2020_08-37-05-385.csv
# Begin, RainFlow
# The damage is 7.929557705638386e-09 %,  Based on 50 % probability of survival
# The damage is 1.855448753814987e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.5040960517695164e-09 %,  Based on 50 % probability of survival
# The damage is 5.859370813816067e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.211536445835563e-07 %,  Based on 50 % probability of survival
# The damage is 5.174806331914669e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.1698756014879975e-07 %,  Based on 50 % probability of survival
# The damage is 2.737408954544855e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.4415961439201428e-07 %,  Based on 50 % probability of survival
# The damage is 4.1175948490399126e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.714928227006985e-05 %,  Based on 50 % probability of survival
# The damage is 4.898306411111126e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.3326888882799056e-06 %,  Based on 50 % probability of survival
# The damage is 9.519075545331135e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2614005829675422e-07 %,  Based on 50 % probability of survival
# The damage is 3.602906795296488e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\01-05-2020_14-37-05-408.csv
# Begin, RainFlow
# The damage is 4.561568145976785e-08 %,  Based on 50 % probability of survival
# The damage is 1.0673679726016171e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.3405508251159599e-08 %,  Based on 50 % probability of survival
# The damage is 3.1367743955232586e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2483990160604055e-06 %,  Based on 50 % probability of survival
# The damage is 2.9211470356865896e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.503905806118803e-06 %,  Based on 50 % probability of survival
# The damage is 1.0538754777357976e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.5633744957441803e-07 %,  Based on 50 % probability of survival
# The damage is 7.321702173213648e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.855337124842251e-05 %,  Based on 50 % probability of survival
# The damage is 0.00028149551836655144 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.6995859014200764e-05 %,  Based on 50 % probability of survival
# The damage is 4.854484511978432e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.28989131339342e-07 %,  Based on 50 % probability of survival
# The damage is 1.7965658539167353e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\01-05-2020_20-37-05-448.csv
# Begin, RainFlow
# The damage is 7.47602155900307e-08 %,  Based on 50 % probability of survival
# The damage is 1.7493251704673104e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.9573971173537987e-08 %,  Based on 50 % probability of survival
# The damage is 4.5801420166634246e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.118329197791632e-06 %,  Based on 50 % probability of survival
# The damage is 4.9567093350208014e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.5647702707019328e-06 %,  Based on 50 % probability of survival
# The damage is 3.661428741121585e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 8.188306361446498e-07 %,  Based on 50 % probability of survival
# The damage is 2.3388053747541505e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.00016584255600331525 %,  Based on 50 % probability of survival
# The damage is 0.00047369192629353524 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.947158502952153e-05 %,  Based on 50 % probability of survival
# The damage is 8.417894791297524e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.122120314916805e-06 %,  Based on 50 % probability of survival
# The damage is 3.205084064764556e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\02-05-2020_02-37-05-486.csv
# Begin, RainFlow
# The damage is 9.349146021358917e-08 %,  Based on 50 % probability of survival
# The damage is 2.187620290880804e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.013675995742021e-08 %,  Based on 50 % probability of survival
# The damage is 4.711829783683866e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.631435660566299e-06 %,  Based on 50 % probability of survival
# The damage is 6.157334618638711e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.110282175733365e-06 %,  Based on 50 % probability of survival
# The damage is 4.937879990933528e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.7219328551716657e-07 %,  Based on 50 % probability of survival
# The damage is 4.918313554562479e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.00021184224342508698 %,  Based on 50 % probability of survival
# The damage is 0.0006050796778383421 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.50855488003122e-05 %,  Based on 50 % probability of survival
# The damage is 0.00010021397159335556 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.1627170622851227e-06 %,  Based on 50 % probability of survival
# The damage is 3.3210395343713186e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\02-05-2020_08-37-05-508.csv
# Begin, RainFlow
# The damage is 3.897308640089015e-09 %,  Based on 50 % probability of survival
# The damage is 9.119369235870117e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0169803756720475e-09 %,  Based on 50 % probability of survival
# The damage is 2.379647189342306e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0728877281966838e-07 %,  Based on 50 % probability of survival
# The damage is 2.5104656175847426e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.530516969349013e-08 %,  Based on 50 % probability of survival
# The damage is 1.0601022625686956e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.752064825118884e-08 %,  Based on 50 % probability of survival
# The damage is 7.860653620589303e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 8.243986035450563e-06 %,  Based on 50 % probability of survival
# The damage is 2.3547090201573553e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.5134276737473557e-06 %,  Based on 50 % probability of survival
# The damage is 4.322765443080829e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.048751086407819e-08 %,  Based on 50 % probability of survival
# The damage is 1.7276895766930604e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\02-05-2020_14-37-05-545.csv
# Begin, RainFlow
# The damage is 4.1981235018466e-09 %,  Based on 50 % probability of survival
# The damage is 9.823250311078465e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.1854130186730296e-09 %,  Based on 50 % probability of survival
# The damage is 2.7737651832572967e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.149336333869924e-07 %,  Based on 50 % probability of survival
# The damage is 2.689348823171917e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.168496746749496e-08 %,  Based on 50 % probability of survival
# The damage is 1.2093840796485045e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.7933122324263706e-08 %,  Based on 50 % probability of survival
# The damage is 5.1221926765698484e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.0028440583263e-06 %,  Based on 50 % probability of survival
# The damage is 2.5714597307723842e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.5695393612200159e-06 %,  Based on 50 % probability of survival
# The damage is 4.483035846329886e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.578936137578928e-08 %,  Based on 50 % probability of survival
# The damage is 1.5934975131627538e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\02-05-2020_20-37-05-566.csv
# Begin, RainFlow
# The damage is 1.324171327136831e-08 %,  Based on 50 % probability of survival
# The damage is 3.0984477696991196e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.242507364584884e-09 %,  Based on 50 % probability of survival
# The damage is 9.92710475777565e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.7571961774549897e-07 %,  Based on 50 % probability of survival
# The damage is 8.791518044367474e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.643232060714059e-07 %,  Based on 50 % probability of survival
# The damage is 6.184937187112504e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2769035621750114e-07 %,  Based on 50 % probability of survival
# The damage is 3.6471875653295285e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.871139946590266e-05 %,  Based on 50 % probability of survival
# The damage is 8.200764898555164e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.2364360755086976e-06 %,  Based on 50 % probability of survival
# The damage is 1.4956700808874932e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.9651622512315248e-07 %,  Based on 50 % probability of survival
# The damage is 5.613043567940376e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\03-05-2020_02-37-05-588.csv
# Begin, RainFlow
# The damage is 7.175154323266828e-08 %,  Based on 50 % probability of survival
# The damage is 1.678924807882946e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.392153728965631e-08 %,  Based on 50 % probability of survival
# The damage is 5.5974353426889344e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.0303925151766506e-06 %,  Based on 50 % probability of survival
# The damage is 4.7509450109191325e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 7.995461675165886e-07 %,  Based on 50 % probability of survival
# The damage is 1.8708697196078598e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.2344468744399e-07 %,  Based on 50 % probability of survival
# The damage is 1.2094744226572186e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.00016346855172139375 %,  Based on 50 % probability of survival
# The damage is 0.00046691111750456497 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.7605359349595437e-05 %,  Based on 50 % probability of survival
# The damage is 7.884849438809732e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.875878782800873e-07 %,  Based on 50 % probability of survival
# The damage is 2.82082244582197e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\03-05-2020_08-37-05-626.csv
# Begin, RainFlow
# The damage is 2.4715312961130132e-08 %,  Based on 50 % probability of survival
# The damage is 5.783172067878213e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.19077242582568e-09 %,  Based on 50 % probability of survival
# The damage is 1.4485878543367899e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.789011519117175e-07 %,  Based on 50 % probability of survival
# The damage is 1.588570690875304e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 8.651099768176722e-07 %,  Based on 50 % probability of survival
# The damage is 2.0242834316697074e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.4138599606945295e-07 %,  Based on 50 % probability of survival
# The damage is 4.0383726857013977e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.345362489810514e-05 %,  Based on 50 % probability of survival
# The damage is 0.00015267824589515686 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.51337609338731e-06 %,  Based on 50 % probability of survival
# The damage is 2.7172817133507105e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.5642219668162423e-07 %,  Based on 50 % probability of survival
# The damage is 1.018039766081009e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\03-05-2020_14-37-05-666.csv
# Begin, RainFlow
# The damage is 5.371645096860563e-09 %,  Based on 50 % probability of survival
# The damage is 1.2569190578964234e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.404181843653267e-09 %,  Based on 50 % probability of survival
# The damage is 3.2856655423334685e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.4586639815132924e-07 %,  Based on 50 % probability of survival
# The damage is 3.4131490900295535e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.573136154784983e-08 %,  Based on 50 % probability of survival
# The damage is 1.538057700037909e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 8.13143745962857e-08 %,  Based on 50 % probability of survival
# The damage is 2.3225620531981337e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.1508107558911563e-05 %,  Based on 50 % probability of survival
# The damage is 3.2870318505372225e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.0602974644749395e-06 %,  Based on 50 % probability of survival
# The damage is 5.884775887470708e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 8.027359119498516e-08 %,  Based on 50 % probability of survival
# The damage is 2.2928344183800515e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\03-05-2020_20-37-05-687.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 4.6545658686320025e-09 %,  Based on 50 % probability of survival
# The damage is 1.089128645140207e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.516341465413247e-07 %,  Based on 50 % probability of survival
# The damage is 1.0567853157617365e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.7796682931292056e-07 %,  Based on 50 % probability of survival
# The damage is 4.1642717529410916e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.634122093119515e-07 %,  Based on 50 % probability of survival
# The damage is 4.667501880959506e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.5057072457485073e-05 %,  Based on 50 % probability of survival
# The damage is 0.00010013263533074196 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.351628183824587e-06 %,  Based on 50 % probability of survival
# The damage is 1.8141996011180804e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.4049063163619106e-07 %,  Based on 50 % probability of survival
# The damage is 6.869073493598287e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\04-05-2020_02-37-05-726.csv
# Begin, RainFlow
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.5606632789910608e-08 %,  Based on 50 % probability of survival
# The damage is 5.991733292470278e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.258228224957921e-06 %,  Based on 50 % probability of survival
# The damage is 5.284061105764649e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 8.865069483677015e-07 %,  Based on 50 % probability of survival
# The damage is 2.0743505169621024e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.0349183397243416e-07 %,  Based on 50 % probability of survival
# The damage is 1.1524835885566831e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.0001767833456097023 %,  Based on 50 % probability of survival
# The damage is 0.0005049418287836894 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.042628478369436e-05 %,  Based on 50 % probability of survival
# The damage is 8.690583283614927e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0595283152628986e-06 %,  Based on 50 % probability of survival
# The damage is 3.026304108635382e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\04-05-2020_08-37-05-748.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 1.4191426255096606e-09 %,  Based on 50 % probability of survival
# The damage is 3.3206724936440106e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.8048001457728557e-07 %,  Based on 50 % probability of survival
# The damage is 4.2230781408882605e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0623796887325732e-07 %,  Based on 50 % probability of survival
# The damage is 2.4858777030345277e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.1350382124370402e-08 %,  Based on 50 % probability of survival
# The damage is 3.241981130918679e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2923187881540134e-05 %,  Based on 50 % probability of survival
# The damage is 3.6912176880207e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.4130123712426793e-06 %,  Based on 50 % probability of survival
# The damage is 6.89222661450795e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 7.795207291165592e-08 %,  Based on 50 % probability of survival
# The damage is 2.2265254748822248e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\04-05-2020_14-37-05-788.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 2.022812761390358e-09 %,  Based on 50 % probability of survival
# The damage is 4.7332090346653665e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.7628036367474262e-07 %,  Based on 50 % probability of survival
# The damage is 4.124809897906185e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 3.036682775606878e-07 %,  Based on 50 % probability of survival
# The damage is 8.673600722186559e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.496761684350334e-05 %,  Based on 50 % probability of survival
# The damage is 4.275162796261365e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.8921832390706323e-06 %,  Based on 50 % probability of survival
# The damage is 8.260870326201779e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.427423432892139e-07 %,  Based on 50 % probability of survival
# The damage is 4.077113690587899e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\04-05-2020_20-37-05-809.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 2.152358932674823e-09 %,  Based on 50 % probability of survival
# The damage is 5.036336007182819e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.0331522779651158e-07 %,  Based on 50 % probability of survival
# The damage is 4.757402620052916e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 8.000564813835802e-08 %,  Based on 50 % probability of survival
# The damage is 1.8720638104559453e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.3376929891785224e-07 %,  Based on 50 % probability of survival
# The damage is 3.820818878482937e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.6171020584835765e-05 %,  Based on 50 % probability of survival
# The damage is 4.618887983618707e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.8869985808325097e-06 %,  Based on 50 % probability of survival
# The damage is 8.246061517129017e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.3140655478501479e-07 %,  Based on 50 % probability of survival
# The damage is 3.753332411402668e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\05-05-2020_02-37-05-848.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 5.75553823977415e-09 %,  Based on 50 % probability of survival
# The damage is 1.3467467733956943e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 7.210561987333551e-07 %,  Based on 50 % probability of survival
# The damage is 1.6872098987552163e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.781657223380652e-07 %,  Based on 50 % probability of survival
# The damage is 6.508840240852472e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.972090047672157e-08 %,  Based on 50 % probability of survival
# The damage is 2.848303027698141e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.729086624986457e-05 %,  Based on 50 % probability of survival
# The damage is 0.0001636384619661864 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.678391553698266e-06 %,  Based on 50 % probability of survival
# The damage is 2.764414664715347e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.581111433716857e-07 %,  Based on 50 % probability of survival
# The damage is 1.0228638620808692e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\05-05-2020_08-37-05-885.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 1.5776901378857602e-09 %,  Based on 50 % probability of survival
# The damage is 3.6916601264719117e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.8834915885647237e-07 %,  Based on 50 % probability of survival
# The damage is 4.407209393707389e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 1.0534857330042346e-07 %,  Based on 50 % probability of survival
# The damage is 3.009044832736156e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.5100254407615088e-05 %,  Based on 50 % probability of survival
# The damage is 4.313047730476752e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.609611952715786e-06 %,  Based on 50 % probability of survival
# The damage is 7.453769059950226e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.3066505757116e-07 %,  Based on 50 % probability of survival
# The damage is 3.732153212767721e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\05-05-2020_14-37-05-909.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 2.0688829598009277e-08 %,  Based on 50 % probability of survival
# The damage is 4.841009362756957e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.392112433257392e-06 %,  Based on 50 % probability of survival
# The damage is 5.597338714259915e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.208832239206956e-07 %,  Based on 50 % probability of survival
# The damage is 2.1547880646833913e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0039126948985632e-06 %,  Based on 50 % probability of survival
# The damage is 2.8674506094052696e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.0001906340736040862 %,  Based on 50 % probability of survival
# The damage is 0.0005445033151858676 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.334307127191674e-05 %,  Based on 50 % probability of survival
# The damage is 9.523697680480209e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2435123749850182e-06 %,  Based on 50 % probability of survival
# The damage is 3.5518131562367244e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\05-05-2020_20-37-05-945.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 7.95620965567759e-09 %,  Based on 50 % probability of survival
# The damage is 1.8616850824127144e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.905590903759335e-07 %,  Based on 50 % probability of survival
# The damage is 2.3178236391561357e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.8267719925914845e-07 %,  Based on 50 % probability of survival
# The damage is 8.95431950730265e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 7.725860975454706e-08 %,  Based on 50 % probability of survival
# The damage is 2.2067182609426416e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 7.799324171362058e-05 %,  Based on 50 % probability of survival
# The damage is 0.00022277013690300113 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.3243707142624547e-05 %,  Based on 50 % probability of survival
# The damage is 3.7827667993321656e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.607895512105154e-07 %,  Based on 50 % probability of survival
# The damage is 1.316141618828399e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\06-05-2020_02-37-05-967.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 9.066261314043461e-09 %,  Based on 50 % probability of survival
# The damage is 2.1214276863060828e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.117206269615759e-06 %,  Based on 50 % probability of survival
# The damage is 2.614167217975962e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.3023823924951143e-07 %,  Based on 50 % probability of survival
# The damage is 1.0067207207426415e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.959228677898862e-07 %,  Based on 50 % probability of survival
# The damage is 5.596095651497885e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.030834015481372e-05 %,  Based on 50 % probability of survival
# The damage is 0.00025794544319161637 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.5077495838924025e-05 %,  Based on 50 % probability of survival
# The damage is 4.306547257677284e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.273115754228825e-07 %,  Based on 50 % probability of survival
# The damage is 1.5061468053709364e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\06-05-2020_08-37-05-990.csv
# Begin, RainFlow
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.4973896393527738e-07 %,  Based on 50 % probability of survival
# The damage is 3.503763820694595e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.55313766279503e-06 %,  Based on 50 % probability of survival
# The damage is 8.314038554607358e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.216971534990225e-06 %,  Based on 50 % probability of survival
# The damage is 1.4547182220388692e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.0764006506591426e-06 %,  Based on 50 % probability of survival
# The damage is 5.930771013612546e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.00023734862152931827 %,  Based on 50 % probability of survival
# The damage is 0.0006779329048274588 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.305954961932946e-05 %,  Based on 50 % probability of survival
# The damage is 0.00012298990980399798 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.460347168465401e-06 %,  Based on 50 % probability of survival
# The damage is 7.027427806635597e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\06-05-2020_14-37-06-028.csv
# Begin, RainFlow
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 7.642109235908041e-10 %,  Based on 50 % probability of survival
# The damage is 1.7881882678274856e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0044836290429741e-07 %,  Based on 50 % probability of survival
# The damage is 2.35040586993912e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.83175934894463e-08 %,  Based on 50 % probability of survival
# The damage is 8.965989495054532e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.414091109346844e-09 %,  Based on 50 % probability of survival
# The damage is 1.2607857541582226e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 7.968977651103223e-06 %,  Based on 50 % probability of survival
# The damage is 2.2761590662325258e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.3164240690340867e-06 %,  Based on 50 % probability of survival
# The damage is 3.7600689962078513e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.26046162899338e-08 %,  Based on 50 % probability of survival
# The damage is 1.2169049516441494e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\06-05-2020_20-37-06-067.csv
# Begin, RainFlow
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.4887134055678577e-08 %,  Based on 50 % probability of survival
# The damage is 3.483462174926151e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.009460524394975e-06 %,  Based on 50 % probability of survival
# The damage is 4.701965940897201e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 7.744065078038899e-07 %,  Based on 50 % probability of survival
# The damage is 1.812045063786148e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2312069532503787e-07 %,  Based on 50 % probability of survival
# The damage is 3.5166654892819363e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.0001531532166112474 %,  Based on 50 % probability of survival
# The damage is 0.0004374476849788933 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.64261574747843e-05 %,  Based on 50 % probability of survival
# The damage is 7.548036969785125e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 8.839716940619243e-07 %,  Based on 50 % probability of survival
# The damage is 2.5248661419616594e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\07-05-2020_02-37-06-107.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# The damage is 5.900213953289693e-10 %,  Based on 50 % probability of survival
# The damage is 1.3805996542642998e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 8.034589555463417e-08 %,  Based on 50 % probability of survival
# The damage is 1.8800253092930034e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.09440509366186e-08 %,  Based on 50 % probability of survival
# The damage is 7.240643536462441e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.575967183735755e-09 %,  Based on 50 % probability of survival
# The damage is 1.0213945228825309e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.3220079968066e-06 %,  Based on 50 % probability of survival
# The damage is 1.8057392615141458e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0406385987446507e-06 %,  Based on 50 % probability of survival
# The damage is 2.9723498859056666e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.3468132263091664e-08 %,  Based on 50 % probability of survival
# The damage is 9.559418537202102e-08 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\07-05-2020_08-37-06-147.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 3.301057559908694e-10 %,  Based on 50 % probability of survival
# The damage is 7.724192651311361e-10 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.321342998322129e-08 %,  Based on 50 % probability of survival
# The damage is 1.0111573405087438e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.5341643532117306e-08 %,  Based on 50 % probability of survival
# The damage is 1.0609557192297092e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.680448010415199e-09 %,  Based on 50 % probability of survival
# The damage is 7.656096311961487e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.7064462551499244e-06 %,  Based on 50 % probability of survival
# The damage is 1.0586629322514348e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.7259087032774e-07 %,  Based on 50 % probability of survival
# The damage is 1.6354769178679113e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.9460345672670194e-08 %,  Based on 50 % probability of survival
# The damage is 5.5584096447723094e-08 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\07-05-2020_14-37-06-168.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 2.106613693790943e-09 %,  Based on 50 % probability of survival
# The damage is 4.929296056619487e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.8519311909001765e-07 %,  Based on 50 % probability of survival
# The damage is 6.673275320714523e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0925682903730006e-07 %,  Based on 50 % probability of survival
# The damage is 2.556516451590856e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.4399438097133984e-08 %,  Based on 50 % probability of survival
# The damage is 4.112875328356345e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.2248160061823304e-05 %,  Based on 50 % probability of survival
# The damage is 6.354686064993648e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.7476253618955136e-06 %,  Based on 50 % probability of survival
# The damage is 1.070424817057996e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2006578517498316e-07 %,  Based on 50 % probability of survival
# The damage is 3.429408858142938e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\07-05-2020_20-37-06-206.csv
# Begin, RainFlow
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.2576642202233956e-08 %,  Based on 50 % probability of survival
# The damage is 5.282741382873828e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.038753188395858e-06 %,  Based on 50 % probability of survival
# The damage is 7.1104228329800675e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.1679165766539286e-06 %,  Based on 50 % probability of survival
# The damage is 2.7328250038101375e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.5241945384533924e-07 %,  Based on 50 % probability of survival
# The damage is 4.353518568247582e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.00023053265396165166 %,  Based on 50 % probability of survival
# The damage is 0.000658464627899685 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.974991747427201e-05 %,  Based on 50 % probability of survival
# The damage is 0.00011353669065508441 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2904305388724772e-06 %,  Based on 50 % probability of survival
# The damage is 3.6858243290358367e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\08-05-2020_02-37-06-229.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 1.7397600653704081e-09 %,  Based on 50 % probability of survival
# The damage is 4.070889909702381e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.3460838943889786e-07 %,  Based on 50 % probability of survival
# The damage is 5.489635865937619e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.041604986157225e-08 %,  Based on 50 % probability of survival
# The damage is 2.1156583162417662e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.5426978130004386e-08 %,  Based on 50 % probability of survival
# The damage is 4.40636900648344e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.868060106059819e-05 %,  Based on 50 % probability of survival
# The damage is 5.3356931501579805e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.089701263890886e-06 %,  Based on 50 % probability of survival
# The damage is 8.825036098302691e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0161527777194545e-07 %,  Based on 50 % probability of survival
# The damage is 2.9024116504622145e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\08-05-2020_08-37-06-266.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 3.257072340751958e-09 %,  Based on 50 % probability of survival
# The damage is 7.621270996535312e-09 %,  Based on 97.7 % probability of survival
# ...
# The damage is 6.999370587856492e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.1413276609920814e-07 %,  Based on 50 % probability of survival
# The damage is 2.6706092128903254e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.7033905972039465e-08 %,  Based on 50 % probability of survival
# The damage is 1.6290451278017962e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.341613027483041e-05 %,  Based on 50 % probability of survival
# The damage is 6.688290462674157e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.139074125602526e-06 %,  Based on 50 % probability of survival
# The damage is 1.1822333440092389e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.4482370144659365e-07 %,  Based on 50 % probability of survival
# The damage is 4.1365630007430267e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\24-05-2020_20-37-08-330.csv
# Begin, RainFlow
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.0971840412109464e-08 %,  Based on 50 % probability of survival
# The damage is 4.9072314752418684e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.427853502987294e-06 %,  Based on 50 % probability of survival
# The damage is 5.680969763748587e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.307372974462818e-07 %,  Based on 50 % probability of survival
# The damage is 2.177845754811619e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.680577877659879e-07 %,  Based on 50 % probability of survival
# The damage is 1.9081566757566256e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.00019137286476064356 %,  Based on 50 % probability of survival
# The damage is 0.0005466135058058857 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.3692108482634925e-05 %,  Based on 50 % probability of survival
# The damage is 9.62339230210071e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2165400593406973e-06 %,  Based on 50 % probability of survival
# The damage is 3.47477280868021e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\25-05-2020_02-37-08-366.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# The damage is 5.449208060233648e-10 %,  Based on 50 % probability of survival
# The damage is 1.2750681286359502e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.759420438708028e-08 %,  Based on 50 % probability of survival
# The damage is 1.5816466308826344e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.580443335175059e-08 %,  Based on 50 % probability of survival
# The damage is 6.038016933953695e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.068175187802447e-08 %,  Based on 50 % probability of survival
# The damage is 3.051001953436996e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.498676219857211e-06 %,  Based on 50 % probability of survival
# The damage is 1.57057307449877e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.500910895109233e-07 %,  Based on 50 % probability of survival
# The damage is 2.7137213100825327e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.124969946657535e-08 %,  Based on 50 % probability of survival
# The damage is 8.925773150843265e-08 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\25-05-2020_08-37-08-389.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 3.163108672907994e-10 %,  Based on 50 % probability of survival
# The damage is 7.401404041937075e-10 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.9275136287085e-08 %,  Based on 50 % probability of survival
# The damage is 9.190046328557354e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.377226421018021e-06 %,  Based on 50 % probability of survival
# The damage is 1.492216496168534e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.188662784653007e-08 %,  Based on 50 % probability of survival
# The damage is 1.4820247158399598e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.1804021396494535e-06 %,  Based on 50 % probability of survival
# The damage is 9.084102731077742e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.853690320337136e-07 %,  Based on 50 % probability of survival
# The damage is 1.671974860126302e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.076437850859516e-08 %,  Based on 50 % probability of survival
# The damage is 1.1643427022138516e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\25-05-2020_14-37-08-427.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 2.5673401993078405e-09 %,  Based on 50 % probability of survival
# The damage is 6.007356715542508e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.5056450833347055e-07 %,  Based on 50 % probability of survival
# The damage is 5.862995415330987e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.515492802330371e-08 %,  Based on 50 % probability of survival
# The damage is 2.226544016378782e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.1727817618388153e-07 %,  Based on 50 % probability of survival
# The damage is 6.206061960117846e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.0492546531521397e-05 %,  Based on 50 % probability of survival
# The damage is 5.853234582915017e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.773714589874662e-06 %,  Based on 50 % probability of survival
# The damage is 1.0778766177024004e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.068829412185535e-07 %,  Based on 50 % probability of survival
# The damage is 5.909145475370613e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\25-05-2020_20-37-08-467.csv
# Begin, RainFlow
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.6618529229903493e-08 %,  Based on 50 % probability of survival
# The damage is 6.228508413892183e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.895566886039435e-06 %,  Based on 50 % probability of survival
# The damage is 6.775379119152638e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.10538195646857e-06 %,  Based on 50 % probability of survival
# The damage is 2.586499335468378e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.6029573310103975e-07 %,  Based on 50 % probability of survival
# The damage is 1.3147311385683642e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.00022800094525210433 %,  Based on 50 % probability of survival
# The damage is 0.0006512333719160555 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.9258660901858464e-05 %,  Based on 50 % probability of survival
# The damage is 0.00011213352684900864 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.3581480782933047e-06 %,  Based on 50 % probability of survival
# The damage is 3.879244235633687e-06 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\26-05-2020_02-37-08-489.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 3.36561433713305e-09 %,  Based on 50 % probability of survival
# The damage is 7.875249994353417e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.617886065649235e-07 %,  Based on 50 % probability of survival
# The damage is 8.465544285250984e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.3588766793267535e-07 %,  Based on 50 % probability of survival
# The damage is 3.1796553286348675e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2065579420400274e-07 %,  Based on 50 % probability of survival
# The damage is 3.4462611378124095e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.948797605852958e-05 %,  Based on 50 % probability of survival
# The damage is 8.422576519734357e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.033513829402879e-06 %,  Based on 50 % probability of survival
# The damage is 1.4377099095284878e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.025892946484126e-07 %,  Based on 50 % probability of survival
# The damage is 5.786507127069166e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\26-05-2020_08-37-08-526.csv
# Begin, RainFlow
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# Begin, RainFlow
# The damage is 3.914963859028137e-09 %,  Based on 50 % probability of survival
# The damage is 9.16068093974438e-09 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.216847932808653e-07 %,  Based on 50 % probability of survival
# The damage is 9.867063879734054e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.5955116069601946e-07 %,  Based on 50 % probability of survival
# The damage is 3.73336084145858e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.100084002635786e-08 %,  Based on 50 % probability of survival
# The damage is 1.742351668592926e-07 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.355681512795725e-05 %,  Based on 50 % probability of survival
# The damage is 9.584748801098025e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.762427062026303e-06 %,  Based on 50 % probability of survival
# The damage is 1.6459075649332528e-05 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 2.001329352952003e-07 %,  Based on 50 % probability of survival
# The damage is 5.716346751968039e-07 %,  Based on 97.7 % probability of survival
# C:\Users\Karabo Mogotlane\Desktop\StackerM\CSV\\26-05-2020_14-37-08-548.csv
# Begin, RainFlow
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:175: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Karabo Mogotlane\anaconda3\lib\site-packages\ipykernel_launcher.py:187: RuntimeWarning: divide by zero encountered in log10
# The damage is 0.0 %,  Based on 50 % probability of survival
# The damage is 0.0 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.059436720373929e-08 %,  Based on 50 % probability of survival
# The damage is 7.158820530629616e-08 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 3.418944520037582e-06 %,  Based on 50 % probability of survival
# The damage is 8.000038065875479e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.2952164396042868e-06 %,  Based on 50 % probability of survival
# The damage is 3.0306958067480054e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.5127478622192216e-06 %,  Based on 50 % probability of survival
# The damage is 4.320823714491745e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.00028344610989532805 %,  Based on 50 % probability of survival
# The damage is 0.0008096000027522664 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 4.780645647084483e-05 %,  Based on 50 % probability of survival
# The damage is 0.00013654838058869433 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.9073247208203332e-06 %,  Based on 50 % probability of survival
# The damage is 5.447843682863888e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 283561528.31344867 %,  Based on 50 % probability of survival
# The damage is 663509749.0556753 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0558259092338702e-06 %,  Based on 50 % probability of survival
# The damage is 2.47054241895557e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.343512284829611e-05 %,  Based on 50 % probability of survival
# The damage is 0.00021863020446669996 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.669170883187304e-05 %,  Based on 50 % probability of survival
# The damage is 0.00015605290059734632 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.184444824613365e-05 %,  Based on 50 % probability of survival
# The damage is 0.0001480819950510507 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.007305928708244224 %,  Based on 50 % probability of survival
# The damage is 0.02086774062444038 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.0012868866617346676 %,  Based on 50 % probability of survival
# The damage is 0.003675702041799012 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.8542178294398e-05 %,  Based on 50 % probability of survival
# The damage is 0.00016721255312260512 %,  Based on 97.7 % probability of survival

# %%
#print(JSONStructure[0]['File']['Channel Data'])
#print(JSONStructure[0]['File']['Channel Data'][1]['Minimum Stress'])
print(JSONStructure[0])
#len(JSONStructure[0]['File']['Channel Data'])
# Out:
# {'File': {'file name': '01-05-2020_02-37-05-347.csv', 'Duration': '1:01:33', 'Channel Data': [{'Channel Name': 'Channel 1.1', '50 Damage': 2.5332804480113898e-08, '97 Damage': 5.927659807538026e-08, 'Minimum Stress': -0.8755826364295723, 'Maximum Stress': 0.05254881568461523}, {'Channel Name': 'Channel 1.2', '50 Damage': 1.027077601583822e-08, '97 Damage': 2.403273835279531e-08, 'Minimum Stress': 0.019226847937168164, 'Maximum Stress': 1.7363884938221914}, {'Channel Name': 'Channel 1.3', '50 Damage': 7.231588757018182e-07, '97 Damage': 1.6921299832109177e-06, 'Minimum Stress': -0.991884227530683, 'Maximum Stress': 1.9760391455245163}, {'Channel Name': 'Channel 1.4', '50 Damage': 1.6914705725617321e-06, '97 Damage': 3.957896622333394e-06, 'Minimum Stress': 0.21394333506415047, 'Maximum Stress': 18.68285524387261}, {'Channel Name': 'Channel 2.1', '50 Damage': 2.7043002202201126e-06, '97 Damage': 7.724224779594495e-06, 'Minimum Stress': 0.4098729623954461, 'Maximum Stress': 35.86146631477222}, {'Channel Name': 'Channel 2.2', '50 Damage': 6.227733408446506e-05, '97 Damage': 0.00017788118476844134, 'Minimum Stress': 0.30917461334168445, 'Maximum Stress': 32.57872418866568}, {'Channel Name': 'Channel 2.3', '50 Damage': 1.1741816199978587e-05, '97 Damage': 3.3537854625451524e-05, 'Minimum Stress': 0.28857560559955897, 'Maximum Stress': 29.231571953729834}, {'Channel Name': 'Channel 2.4', '50 Damage': 6.932582493606343e-07, '97 Damage': 1.9801361211048736e-06, 'Minimum Stress': 0.19351961859721348, 'Maximum Stress': 17.518631602036052}]}}

# %%
########################################################
##########     POST PROCESSING OF DATASET   ###########
#######################################################

dataset = []
channelList = ['Channel 1.1', 'Channel 1.2','Channel 1.3','Channel 1.4','Channel 2.1','Channel 2.2','Channel 2.3','Channel 2.4']
for j in range(len(Channels)):
    dataset.append({
        'name' : Channels[j],
        '50 Damage' : 0 ,
        '97 Damage':0,
        'Stress Range':[],
        'Maximum Stress Range':0,
    })  
for i in range(len(JSONStructure)):#Loop throguh the JSON object , and view each file name.
    for j in range(len(JSONStructure[i]['File']['Channel Data'])): #Loop through the channel data to view each channel dataset.      
        ChannelName = JSONStructure[i]['File']['Channel Data'][j]['Channel Name'] # define a variable to channelname.
       
        for j in range(len(Channels)):#Loop through the summary data array and find the place to put the data.
            if ChannelName == dataset[j]['name']:#Check that the right channel has been found.
                dataset[j]['50 Damage'] = dataset[j]['50 Damage'] + JSONStructure[i]['File']['Channel Data'][j]['50 Damage']#Add the data sets together into the storage array.
                dataset[j]['97 Damage'] = dataset[j]['97 Damage'] + JSONStructure[i]['File']['Channel Data'][j]['97 Damage']#Add the data sets together into the storage array.
                dataset[j]['Stress Range'].append(JSONStructure[i]['File']['Channel Data'][j]['Maximum Stress'] -JSONStructure[i]['File']['Channel Data'][j]['Minimum Stress']) # Calculate stress range 
#print(dataset)                
for i in range(len(dataset)):
    dataset[i]['Maximum Stress Range']  = max(dataset[i]['Stress Range']) 
    dataset[i].pop('Stress Range')
print(dataset[3])
print(dataset[7])
# Out:
# {'name': 'Channel 1.4', '50 Damage': 5.561875471068026e-05, '97 Damage': 0.00013014313401527242, 'Maximum Stress Range': 18.255465250128854}
# {'name': 'Channel 2.4', '50 Damage': 4.705996598054054e-05, '97 Damage': 0.0001344161985551213, 'Maximum Stress Range': 22.576412434059662}

# %%
FailPerYr = (365*24*60*dataset[3]['97 Damage']/100)/402

print((1/FailPerYr),'Years to fail')
# Out:
# 643.688941317843 Years to fail

# %%
import pymongo #import the pymongo pip
import datetime
#mongodb://heroku_6x00zflw:muikokfevp1h13d5pu0ph74p21@ds161109.mlab.com:61109/heroku_6x00zflw
from pymongo import MongoClient
client = MongoClient('mongodb://heroku_6x00zflw:muikokfevp1h13d5pu0ph74p21@ds161109.mlab.com:61109/heroku_6x00zflw?retryWrites=false')
db = client.test_database
db = client['heroku_6x00zflw']
collection = db['fines']
 
post = {"author": "jon",
        'data':JSONStructure,
        'summary':dataset,
       }
post_id = collection.insert_one(post)

# %%
 df = pandas.read_csv('SampleSignal.csv', delimiter=',',low_memory=False)
df
# Out:
#      Unnamed: 0  Channel 1.1  Channel 1.2  Channel 1.3  Channel 1.4  \
# 0             0           74            1          121          225
# 1             1           30          106          116          199
# 2             2           84          196          113           58
# 3             3          106           53           25          148
# 4             4            3          181           73          258
# ..          ...          ...          ...          ...          ...
# 995         995           62           16          154           10
# 996         996          152          223          191           61
# 997         997           56          155           32           30
# 998         998          170           98          132          186
# 999         999          150          203            2           16
#
#      Channel 2.1  Channel 2.2  Channel 2.3  Channel 2.4
# 0            109           68           30            7
# 1             91          184          160          162
# 2            147          250          154          152
# 3            190          214           76          123
# 4            212          124          173           25
# ..           ...          ...          ...          ...
# 995           39          128          148          181
# 996          219           17          148          113
# 997            1          242           31          203
# 998          125          226          132          158
# 999           77           58            4          176
#
# [1000 rows x 9 columns]

# %%
for Channel in Channels:
    print(Channel)
    #RainFlow(FilteredSignal(df[Channel]),Channel)
a = rainflow.count_cycles(GetChannelData(df[Channel])[0])
#print(a)
rng = []
Mean =[]
Cycles =[]
for Extract in rainflow.extract_cycles(GetChannelData(df['Channel 1.2'])[0]): 
    rng.append(round(Extract[0],4))
    Mean.append(round(Extract[1],4))
    Cycles.append(Extract[2])
Mean
# Out:
# Channel 1.1
# Channel 1.2
# Channel 1.3
# Channel 1.4
# Channel 2.1
# Channel 2.2
# Channel 2.3
# Channel 2.4
# [4.6665,
#  3.9046,
#  4.4569,
#  3.2379,
#  4.2665,
#  3.3903,
#  3.4856,
#  4.876,
#  4.7426,
#  3.9808,
#  3.8474,
#  3.9046,
#  4.9331,
#  5.2188,
#  4.2474,
#  7.1044,
#  5.4283,
#  6.2092,
#  2.7046,
#  3.276,
#  5.0664,
#  5.314,
#  5.9045,
#  4.3236,
#  3.9046,
#  4.1903,
#  1.9999,
#  1.619,
#  3.5808,
#  4.2665,
#  4.6855,
#  4.9141,
#  2.7618,
#  4.9902,
#  6.1711,
#  2.8761,
#  4.5712,
#  4.9712,
#  4.9522,
#  4.7617,
#  4.3998,
#  6.2473,
#  5.1998,
#  4.6855,
#  5.5045,
#  7.2568,
#  4.7807,
#  4.5712,
#  3.1046,
#  4.7998,
#  3.8284,
#  4.3617,
#  4.8188,
#  5.8474,
#  5.1617,
#  4.4379,
#  2.5713,
#  3.6379,
#  1.4476,
#  3.3141,
#  4.0379,
#  4.0189,
#  4.3046,
#  5.0093,
#  4.476,
#  4.6855,
#  7.9996,
#  6.6854,
#  4.1141,
#  6.2664,
#  4.6855,
#  4.6474,
#  4.6474,
#  4.6855,
#  5.5426,
#  5.9997,
#  3.5236,
#  4.895,
#  4.9522,
#  4.1331,
#  4.6665,
#  4.5903,
#  5.1617,
#  6.9521,
#  4.3998,
#  3.2189,
#  4.1141,
#  3.1046,
#  2.3999,
#  5.0093,
#  5.1807,
#  4.6665,
#  4.5141,
#  4.7807,
#  4.8188,
#  6.095,
#  4.9902,
#  2.7237,
#  4.9522,
#  4.7617,
#  3.8093,
#  3.1808,
#  4.9141,
#  4.7807,
#  4.095,
#  5.4283,
#  4.4379,
#  4.076,
#  6.3045,
#  4.6474,
#  2.2475,
#  4.2093,
#  5.0283,
#  4.2474,
#  4.4569,
#  4.2665,
#  5.5426,
#  4.7236,
#  4.7426,
#  5.7712,
#  6.2854,
#  4.6284,
#  1.7713,
#  2.7808,
#  4.057,
#  5.295,
#  5.2188,
#  4.5141,
#  7.2759,
#  4.5141,
#  7.352,
#  3.7903,
#  6.2854,
#  5.0664,
#  4.6665,
#  5.6188,
#  4.8188,
#  3.5046,
#  3.9617,
#  4.7998,
#  5.7712,
#  5.2569,
#  6.3045,
#  7.0854,
#  5.9235,
#  4.5903,
#  4.8188,
#  6.7235,
#  5.0283,
#  5.1236,
#  1.9809,
#  4.7426,
#  6.0759,
#  6.0759,
#  4.4188,
#  5.7521,
#  5.5616,
#  4.6474,
#  5.0855,
#  5.0664,
#  4.6284,
#  4.9522,
#  3.4856,
#  3.6189,
#  5.1807,
#  4.6855,
#  5.0283,
#  4.7045,
#  4.6665,
#  4.2665,
#  4.2284,
#  1.6571,
#  4.076,
#  4.2855,
#  3.2189,
#  4.3998,
#  4.2855,
#  4.7236,
#  5.5616,
#  5.7521,
#  4.895,
#  4.5522,
#  5.2188,
#  5.5997,
#  4.476,
#  6.6283,
#  6.533,
#  4.9141,
#  6.3426,
#  3.5617,
#  4.9902,
#  4.7236,
#  3.276,
#  7.0092,
#  5.8093,
#  4.876,
#  4.9522,
#  4.6665,
#  4.7236,
#  3.4284,
#  4.4569,
#  4.057,
#  5.7521,
#  5.6188,
#  4.7998,
#  7.5616,
#  6.0188,
#  4.7045,
#  4.8188,
#  6.914,
#  4.6474,
#  4.1522,
#  4.5522,
#  3.9236,
#  5.6569,
#  5.7902,
#  8.7425,
#  4.7045,
#  4.895,
#  4.9712,
#  4.9712,
#  5.0855,
#  8.6472,
#  4.2855,
#  5.1426,
#  5.1236,
#  3.7522,
#  4.3046,
#  4.7236,
#  4.895,
#  4.095,
#  5.6569,
#  1.9618,
#  4.1141,
#  7.2568,
#  4.8569,
#  5.0474,
#  4.6474,
#  3.7522,
#  4.5712,
#  4.5331,
#  3.6951,
#  6.2283,
#  8.1711,
#  8.0758,
#  4.3617,
#  3.7713,
#  4.3808,
#  4.8188,
#  3.7713,
#  3.5808,
#  2.5713,
#  3.1999,
#  3.4284,
#  3.9046,
#  3.4475,
#  5.6188,
#  4.095,
#  4.9522,
#  4.2093,
#  5.6378,
#  3.657,
#  4.7617,
#  4.6093,
#  4.6474,
#  3.4284,
#  4.8188,
#  4.6665,
#  4.895,
#  6.914,
#  4.6855,
#  5.4855,
#  4.5522,
#  5.2379,
#  5.0283,
#  3.9427,
#  4.2855,
#  5.2569,
#  4.7045,
#  4.7426,
#  4.7426,
#  2.5904,
#  5.1236,
#  4.7426,
#  4.3808,
#  6.0569,
#  5.2569,
#  5.3331,
#  5.2759,
#  5.5997,
#  4.8569,
#  5.9807,
#  4.6093,
#  5.0664,
#  5.0283,
#  4.8188,
#  6.6473,
#  5.295,
#  6.3807,
#  5.6188,
#  6.6092,
#  5.0474,
#  3.8855,
#  6.2664,
#  6.3997,
#  6.2664,
#  4.7236,
#  4.6855,
#  4.895,
#  4.9522,
#  4.8379,
#  6.4759,
#  5.1045,
#  4.7236,
#  4.7236,
#  4.2474,
#  4.3998,
#  2.457,
#  4.2284,
#  1.9618,
#  3.1808,
#  2.6285,
#  4.6284,
#  5.0855,
#  5.5236,
#  2.4761,
#  4.2855,
#  4.5141,
#  4.7426,
#  4.7045,
#  4.7807,
#  4.3236,
#  6.114,
#  5.7331]

# %%
RainFlow(FilteredSignal(df['Channel 1.1']),'Channel 1.1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-174-97b649a799e7> in <module>
# ----> 1 RainFlow(FilteredSignal(df['Channel 1.1']),'Channel 1.1')
#
# <ipython-input-173-8cbe64f96030> in FilteredSignal(Channel)
#      97     fc = 16  # Cut-off frequency of the filter
#      98     w = fc / (fs / 2) # Normalize the frequency
# ---> 99     b, a = sig.butter(8, w, 'low')
#     100     #output = signal.filtfilt(b, a, signalc)
#     101     x_filt = sig.lfilter(b, a, GetChannelData(Channel)[0])
#
# ~\anaconda3\lib\site-packages\scipy\signal\filter_design.py in butter(N, Wn, btype, analog, output, fs)
#    2865     """
#    2866     return iirfilter(N, Wn, btype=btype, analog=analog,
# -> 2867                      output=output, ftype='butter', fs=fs)
#    2868
#    2869
#
# ~\anaconda3\lib\site-packages\scipy\signal\filter_design.py in iirfilter(N, Wn, rp, rs, btype, analog, ftype, output, fs)
#    2344     if not analog:
#    2345         if numpy.any(Wn <= 0) or numpy.any(Wn >= 1):
# -> 2346             raise ValueError("Digital filter critical frequencies "
#    2347                              "must be 0 < Wn < 1")
#    2348         fs = 2.0
#
# ValueError: Digital filter critical frequencies must be 0 < Wn < 1

# %%
d1 = {'range': rng,'Cycles':Cycles,'Mean':Mean}
df2 = pandas.DataFrame(d1)
print(df2)   
Markov=df2.pivot_table(values='Cycles', index='range', columns='Mean')

print(Markov)
finaldf = pandas.DataFrame(Markov)
finaldf.to_csv('Output_Real_Sample1.csv', index=True, header=True)
# Out:
#       range  Cycles    Mean
# 0    1.7904     1.0  4.6665
# 1    3.5427     1.0  3.9046
# 2    4.8760     1.0  4.4569
# 3    2.6665     1.0  3.2379
# 4    6.3997     1.0  4.2665
# ..      ...     ...     ...
# 329  9.4091     0.5  4.7045
# 330  9.2567     0.5  4.7807
# 331  8.3425     0.5  4.3236
# 332  4.7617     0.5  6.1140
# 333  3.9998     0.5  5.7331
#
# [334 rows x 3 columns]
# Mean    1.4476  1.6190  1.6571  1.7713  1.9618  1.9809  1.9999  2.2475  \
# range
# 0.0381     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 0.1524     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 0.2286     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 0.2667     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 0.3047     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 9.3329     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9.3710     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9.4091     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9.4472     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 9.4853     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# Mean    2.3999  2.4570  ...  7.1044  7.2568  7.2759  7.3520  7.5616  7.9996  \
# range                   ...
# 0.0381     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 0.1524     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 0.2286     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 0.2667     NaN     NaN  ...     NaN     1.0     NaN     NaN     NaN     NaN
# 0.3047     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# ...        ...     ...  ...     ...     ...     ...     ...     ...     ...
# 9.3329     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 9.3710     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 9.4091     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 9.4472     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 9.4853     NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# Mean    8.0758  8.1711  8.6472  8.7425
# range
# 0.0381     NaN     NaN     NaN     NaN
# 0.1524     NaN     NaN     1.0     NaN
# 0.2286     NaN     NaN     NaN     NaN
# 0.2667     NaN     NaN     NaN     NaN
# 0.3047     1.0     NaN     NaN     NaN
# ...        ...     ...     ...     ...
# 9.3329     NaN     NaN     NaN     NaN
# 9.3710     NaN     NaN     NaN     NaN
# 9.4091     NaN     NaN     NaN     NaN
# 9.4472     NaN     NaN     NaN     NaN
# 9.4853     NaN     NaN     NaN     NaN
#
# [179 rows x 173 columns]

# %%
#RandomData_out
Df= pandas.read_csv('RandomData_out.csv', delimiter=',',low_memory=False)
Df
# Out:
#            count      Time  Channel 1.1  Channel 1.2  Channel 1.3  \
# 0              1      0.00         40.0         0.00          4.0
# 1              2      0.02        120.0       125.33         12.0
# 2              3      0.04        200.0       248.69         20.0
# 3              4      0.06        280.0       368.12         28.0
# 4              5      0.08        360.0       481.75         36.0
# ...          ...       ...          ...          ...          ...
# 1048563  1048564  20971.26        920.0       998.03         92.0
# 1048564  1048565  20971.28        840.0       982.29         84.0
# 1048565  1048566  20971.30        760.0       951.06         76.0
# 1048566  1048567  20971.32        680.0       904.83         68.0
# 1048567  1048568  20971.34        600.0       844.33         60.0
#
#          Channel 1.4  Channel 2.1  Channel 2.2  Channel 2.3  Channel 2.4
# 0               40.0         0.32         20.0         40.0         40.0
# 1              120.0         0.10         60.0        120.0        120.0
# 2              200.0        -2.19        100.0        200.0        200.0
# 3              280.0         0.23        140.0        280.0        280.0
# 4              360.0        -0.71        180.0        360.0        360.0
# ...              ...          ...          ...          ...          ...
# 1048563        920.0        -2.40        460.0        920.0        920.0
# 1048564        840.0         0.38        420.0        840.0        840.0
# 1048565        760.0        -1.55        380.0        760.0        760.0
# 1048566        680.0        -0.55        340.0        680.0        680.0
# 1048567        600.0         0.89        300.0        600.0        600.0
#
# [1048568 rows x 10 columns]

# %%
RainFlow(FilteredSignal(Df['Channel 1.4']), 'Channel 1.4')
# Out:
# Begin, RainFlow
# The damage is 2.434604120935244 %,  Based on 50 % probability of survival
# The damage is 5.696765632981118 %,  Based on 97.7 % probability of survival
# [2.434604120935244, 5.696765632981118]

# %%
for Channel in Channels:
        #print(Channel)
        #FileResults.append(Channel) # store Channel name
        ab1 = FilteredSignal(RawData[Channel])
        #print(Channel)
        ab2 = RainFlow(ab1,Channel)
# Out:
# Begin, RainFlow
# The damage is 283561528.31344867 %,  Based on 50 % probability of survival
# The damage is 663509749.0556753 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 1.0558259092338702e-06 %,  Based on 50 % probability of survival
# The damage is 2.47054241895557e-06 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 9.343512284829611e-05 %,  Based on 50 % probability of survival
# The damage is 0.00021863020446669996 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 6.669170883187304e-05 %,  Based on 50 % probability of survival
# The damage is 0.00015605290059734632 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.184444824613365e-05 %,  Based on 50 % probability of survival
# The damage is 0.0001480819950510507 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.007305928708244224 %,  Based on 50 % probability of survival
# The damage is 0.02086774062444038 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 0.0012868866617346676 %,  Based on 50 % probability of survival
# The damage is 0.003675702041799012 %,  Based on 97.7 % probability of survival
# Begin, RainFlow
# The damage is 5.8542178294398e-05 %,  Based on 50 % probability of survival
# The damage is 0.00016721255312260512 %,  Based on 97.7 % probability of survival

# %%
import numpy as np
from scipy.signal import butter, lfilter, freqz
import matplotlib.pyplot as plt


def butter_lowpass(cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=5):
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = lfilter(b, a, data)
    return y


# Filter requirements.
order = 6
fs = 30.0       # sample rate, Hz
cutoff = 3.667  # desired cutoff frequency of the filter, Hz

# Get the filter coefficients so we can check its frequency response.
b, a = butter_lowpass(cutoff, fs, order)

# Plot the frequency response.
w, h = freqz(b, a, worN=8000)
plt.subplot(2, 1, 1)
plt.plot(0.5*fs*w/np.pi, np.abs(h), 'b')
plt.plot(cutoff, 0.5*np.sqrt(2), 'ko')
plt.axvline(cutoff, color='k')
plt.xlim(0, 0.5*fs)
plt.title("Lowpass Filter Frequency Response")
plt.xlabel('Frequency [Hz]')
plt.grid()


# Demonstrate the use of the filter.
# First make some data to be filtered.
T = 5.0         # seconds
n = int(T * fs) # total number of samples
t = np.linspace(0, T, n, endpoint=False)
# "Noisy" data.  We want to recover the 1.2 Hz signal from this.
data = np.sin(1.2*2*np.pi*t) + 1.5*np.cos(9*2*np.pi*t) + 0.5*np.sin(12.0*2*np.pi*t)

# Filter the data, and plot both the original and filtered signals.
y = butter_lowpass_filter(data, cutoff, fs, order)

plt.subplot(2, 1, 2)
plt.plot(t, data, 'b-', label='data')
plt.plot(t, y, 'g-', linewidth=2, label='filtered data')
plt.xlabel('Time [sec]')
plt.grid()
plt.legend()

plt.subplots_adjust(hspace=0.35)
plt.show()
