# %%
########################################## LUMPY STACKER - KOLOMELA ##########################################

# %%
#INSTRUCTIONS:
#1. Ensure the CSV's have been pushed to the Mongocloud. 

#Google Drive Functional Spec
#https://docs.google.com/document/d/1DxqJCOKn40OIKej5CaKQ3CNnHxVCJO3I2LFPDUv4V0I/edit#

#User Manual
#https://docs.google.com/document/d/1qL2m3qvlNFPelwpigaVLsu8i0OQEmeqqw3ghwsF5W4E/edit?usp=sharing

# %%
#Troubleshooting notes
#1. When loading modules, they remain loaded on the page , and deleteing the import can cause unexpected errors.
#2. a .env file with passwords etc is required for mongodb access.

# %%
#Required tests.
#1.Review and confirm the Weld class and Guage factor calcuation as well as the values . 
#2.The newly installed gagues have lower guage factors.
#3.Work was done to understand the use of filtering , however this was discarded , and not well documented. Review the forward and F/b pass filterin.

# %%
machine = "lumpy"
path = 'C:/Users/jdavi/Desktop/Lumpy April/d/'

# %%
#This is a file stream function , and as such requries a "promise" for inline code, wont work in the cell as is below. 
from pathlib import Path
from dotenv import load_dotenv # add this line
import os
env_path = Path('.') / '.env'
load_dotenv(dotenv_path=env_path)

THIS_MACHINE_ENV = os.getenv('THIS_MACHINE_ENV')

if(THIS_MACHINE_ENV != machine):
    print("TEST FAIL : .ENV is incorrect or out of date.")

# A missing or out-of-date .env file can cause errors in a software project.
# The .env file stores important configuration information and environment variables needed for the software to function correctly.
# If this information is missing or incorrect, the software may not be able to connect to databases or third-party services, or may not be able to access other critical resources.
# For example, in a Node.js application, if a database connection string is stored in the .env file and the file is missing or contains an outdated connection string, the application will not be able to connect to the database, causing errors or failure to function correctly.
# Similarly, if an API key or other authentication credentials are stored in the .env file and are missing or out-of-date, the software may not be able to authenticate with third-party services or may be denied access to critical resources.
# In summary, the .env file is a critical component of many software projects that store sensitive data and configurations. It should be kept up-to-date and include all necessary environment variables to ensure the software functions correctly.

# %%
#CONNECT TO REMOTE MONGODB  
import pymongo #import the pymongo pip
import datetime #pip module for handling date and time
from pymongo import MongoClient #mongodb management
import os
import certifi #pip module for SSL certificates
user = os.getenv('MYSQL_USER')
userPC = os.environ['COMPUTERNAME'] # WORK ONLY ON WINDOWS
password = os.getenv('MYSQL_PASSWORD')
host = os.getenv('MYSQL_HOST')
COLLECTIONCSVFILES = os.getenv('COLLECTIONCSVFILES')
conn_text = 'mongodb+srv://{}:{}@{}/?retryWrites=true&w=majority'.format(user,password,host)
client = MongoClient(conn_text, tlsCAFile=certifi.where())
db = client.entangelment
collection = db[COLLECTIONCSVFILES]

# Adjust the MongoDB query to filter for documents where the "comment" field matches the "path" variable
query = {"comment": path}

# Use the find() method instead of find_one() to get all matching documents
dataset = list(collection.find(query).sort('_id', pymongo.DESCENDING))

# Check if the query returned more than one document
if len(dataset) > 1:
    raise ValueError("The query returned more than one document. Please adjust the query to return a single document.")

# If the query returned exactly one document, proceed with the rest of the code
dataset = dataset[0]

mainarray = {} #initialize the main array

#  PRINT THE LIST BOX FOR PROCESSING 
import ipywidgets as widgets

filenamelist = [] #initialize the csv array of filenames
channels = ['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4', 'Channel 2.1', 'Channel 2.2', 'Channel 2.3', 'Channel 2.4']
for i in dataset['date']: #create a list of filenames.
    dataloop = i['filename']
    filenamelist.append(dataloop)
mainarray = {
  "File Name": filenamelist,
  "Channel": channels
}
print(mainarray)
print("Receive CSV list from Server - Complete")
# Out:
# {'File Name': ['16-04-2023_00-59-07-691.csv', '16-04-2023_06-59-07-731.csv', '16-04-2023_12-59-07-769.csv', '16-04-2023_18-59-07-809.csv', '17-04-2023_00-59-07-849.csv', '17-04-2023_06-59-07-889.csv', '17-04-2023_12-59-07-912.csv', '17-04-2023_18-59-07-947.csv', '18-04-2023_00-59-07-969.csv', '18-04-2023_06-59-07-992.csv', '18-04-2023_12-59-08-028.csv', '18-04-2023_18-59-08-052.csv', '19-04-2023_00-59-08-088.csv', '19-04-2023_06-59-08-111.csv', '19-04-2023_12-59-08-151.csv', '19-04-2023_18-59-08-188.csv', '20-04-2023_00-59-08-210.csv', '20-04-2023_06-59-08-249.csv', '20-04-2023_12-59-08-309.csv', '20-04-2023_18-59-08-330.csv', '21-04-2023_00-59-08-369.csv', '21-04-2023_06-59-08-390.csv', '21-04-2023_12-59-08-429.csv', '21-04-2023_18-59-08-450.csv', '27-04-2023_23-46-50-249.csv', '28-04-2023_05-46-50-272.csv', '28-04-2023_11-46-50-310.csv', '28-04-2023_17-46-50-350.csv', '28-04-2023_23-46-50-387.csv', '29-04-2023_05-46-50-408.csv', '29-04-2023_11-46-50-431.csv', '29-04-2023_17-46-50-469.csv', '29-04-2023_23-46-50-491.csv', '30-04-2023_05-46-50-529.csv', '30-04-2023_11-46-50-551.csv', '30-04-2023_17-46-50-590.csv', '30-04-2023_23-46-50-628.csv'], 'Channel': ['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4', 'Channel 2.1', 'Channel 2.2', 'Channel 2.3', 'Channel 2.4']}
# Receive CSV list from Server - Complete

# %%
# Importing Modules
import numpy as np
import pandas
import glob # module for reading files from a directory
import os # module for getting only the filename not the whole path
from datetime import datetime
from datetime import datetime, timedelta 
import csv
import json
    
########### GLOBAL VARIABLES 
Files =[]
JSONStructure = []
Channels = [] 
tempVar= []
tempVar2= []
 
########  CONSTRUCT JSON OBJECT FOR DATA PROCESSING 
filecount = len([name for name in os.listdir(path) if os.path.isfile(os.path.join(path, name))])
for i in range(len(mainarray['File Name'])):
    Files.append(path+mainarray['File Name'][i])
    with open(path+mainarray['File Name'][i]) as file:
        print(path+mainarray['File Name'][i] +" "+ str(i) + "/" + str(filecount))
        x = pandas.read_csv(file, delimiter=';',low_memory=False)#read in each CSV file
        #Extract the start and end times on each CSV file
        startTime= str(x.iloc[[0]]['Time'].values[0]) # string extract of start and end times for CSV
        EndTime= str(x.iloc[[-5]]['Time'].values[0]) # string extract of start and end times for CSV
        if startTime[11:13] =='24':
            #print(int(startTime[11:13]))
            startTime= str(0)+str(int(startTime[:1])+1)+startTime[2:10]+"_"+str(startTime[11:13].replace("24","00"))+"-"+startTime[14:]
        if EndTime[11:13] =='24':
            #print(int(EndTime[11:13])+1)
            EndTime= str(0)+ str(int(EndTime[:1])+1)+EndTime[2:10]+"_"+str(EndTime[11:13].replace("24","00"))+"-"+EndTime[14:]
        dateObject = str(startTime[0:10]).replace("-", " ")
        timeObject = str(startTime[11:19]).replace("-", " ")
        total = dateObject+' '+timeObject
        dateObject = datetime.strptime(total, '%d %m %Y %H %M %S')
        startTimeStr = str(dateObject)
        startTime = dateObject
        dateObject = str(EndTime[0:10]).replace("-", " ")
        timeObject = str(EndTime[11:19]).replace("-", " ")
        total = dateObject+' '+timeObject
        dateObject = datetime.strptime(total, '%d %m %Y %H %M %S')
        EndTimeStr = str(dateObject)
        EndTime = dateObject
        duration = EndTime - startTime
        if duration.days == 1:
            duration=duration-timedelta(days=1)
        if duration.days == -1:
            duration=duration+timedelta(days=1) 
        if duration.days == 2:
            duration=duration-timedelta(days=2)
        tempVarArray= []
        for Channel in mainarray['Channel']:
            Channel = Channel.strip('\"')
            Channels.append(Channel)        
            tempVar =   { 'Channel Name':Channel,
                        }
            tempVarArray.append(tempVar)
        tempVar2 = {
            "File" : {
                    'file name':mainarray['File Name'][i],
                    "Duration": str(duration),
                    "Channel Data" : tempVarArray,
                    }
        }               
        JSONStructure.append(tempVar2)
        #file.close()
#NFI
Channels = list(dict.fromkeys(Channels)) # remove duplicates inside the channel list
print("complete")
# Out:
# C:/Users/jdavi/Desktop/Lumpy April/d/16-04-2023_00-59-07-691.csv 0/37
# C:/Users/jdavi/Desktop/Lumpy April/d/16-04-2023_06-59-07-731.csv 1/37
# C:/Users/jdavi/Desktop/Lumpy April/d/16-04-2023_12-59-07-769.csv 2/37
# C:/Users/jdavi/Desktop/Lumpy April/d/16-04-2023_18-59-07-809.csv 3/37
# C:/Users/jdavi/Desktop/Lumpy April/d/17-04-2023_00-59-07-849.csv 4/37
# C:/Users/jdavi/Desktop/Lumpy April/d/17-04-2023_06-59-07-889.csv 5/37
# C:/Users/jdavi/Desktop/Lumpy April/d/17-04-2023_12-59-07-912.csv 6/37
# C:/Users/jdavi/Desktop/Lumpy April/d/17-04-2023_18-59-07-947.csv 7/37
# C:/Users/jdavi/Desktop/Lumpy April/d/18-04-2023_00-59-07-969.csv 8/37
# C:/Users/jdavi/Desktop/Lumpy April/d/18-04-2023_06-59-07-992.csv 9/37
# C:/Users/jdavi/Desktop/Lumpy April/d/18-04-2023_12-59-08-028.csv 10/37
# C:/Users/jdavi/Desktop/Lumpy April/d/18-04-2023_18-59-08-052.csv 11/37
# C:/Users/jdavi/Desktop/Lumpy April/d/19-04-2023_00-59-08-088.csv 12/37
# C:/Users/jdavi/Desktop/Lumpy April/d/19-04-2023_06-59-08-111.csv 13/37
# C:/Users/jdavi/Desktop/Lumpy April/d/19-04-2023_12-59-08-151.csv 14/37
# C:/Users/jdavi/Desktop/Lumpy April/d/19-04-2023_18-59-08-188.csv 15/37
# C:/Users/jdavi/Desktop/Lumpy April/d/20-04-2023_00-59-08-210.csv 16/37
# C:/Users/jdavi/Desktop/Lumpy April/d/20-04-2023_06-59-08-249.csv 17/37
# C:/Users/jdavi/Desktop/Lumpy April/d/20-04-2023_12-59-08-309.csv 18/37
# C:/Users/jdavi/Desktop/Lumpy April/d/20-04-2023_18-59-08-330.csv 19/37
# C:/Users/jdavi/Desktop/Lumpy April/d/21-04-2023_00-59-08-369.csv 20/37
# C:/Users/jdavi/Desktop/Lumpy April/d/21-04-2023_06-59-08-390.csv 21/37
# C:/Users/jdavi/Desktop/Lumpy April/d/21-04-2023_12-59-08-429.csv 22/37
# C:/Users/jdavi/Desktop/Lumpy April/d/21-04-2023_18-59-08-450.csv 23/37
# C:/Users/jdavi/Desktop/Lumpy April/d/27-04-2023_23-46-50-249.csv 24/37
# C:/Users/jdavi/Desktop/Lumpy April/d/28-04-2023_05-46-50-272.csv 25/37
# C:/Users/jdavi/Desktop/Lumpy April/d/28-04-2023_11-46-50-310.csv 26/37
# C:/Users/jdavi/Desktop/Lumpy April/d/28-04-2023_17-46-50-350.csv 27/37
# C:/Users/jdavi/Desktop/Lumpy April/d/28-04-2023_23-46-50-387.csv 28/37
# C:/Users/jdavi/Desktop/Lumpy April/d/29-04-2023_05-46-50-408.csv 29/37
# C:/Users/jdavi/Desktop/Lumpy April/d/29-04-2023_11-46-50-431.csv 30/37
# C:/Users/jdavi/Desktop/Lumpy April/d/29-04-2023_17-46-50-469.csv 31/37
# C:/Users/jdavi/Desktop/Lumpy April/d/29-04-2023_23-46-50-491.csv 32/37
# C:/Users/jdavi/Desktop/Lumpy April/d/30-04-2023_05-46-50-529.csv 33/37
# C:/Users/jdavi/Desktop/Lumpy April/d/30-04-2023_11-46-50-551.csv 34/37
# C:/Users/jdavi/Desktop/Lumpy April/d/30-04-2023_17-46-50-590.csv 35/37
# C:/Users/jdavi/Desktop/Lumpy April/d/30-04-2023_23-46-50-628.csv 36/37
# complete

# %%
#Importing Modules 
import matplotlib.pyplot as plt
import numpy as np
from math import pi
import scipy.fftpack as sf
import scipy.signal as sig
import rainflow
import pandas
import glob # module for reading files from a directory
import os # module for getting only the filename not the whole path
from pylab import*
import json
import csv

#DEFINE GLOBAL VARIABLES
Slot1=['Channel 1.1', 'Channel 1.2', 'Channel 1.3', 'Channel 1.4'] 
Files =[] # empty array to store Files
ChannelData = []

Corr1 = 0.1840265*0.207 # Channel 1.1 to 1.4 weld class W
Corr2 = 0.4784689*0.207 # Channel 2.1 to 2.4 weld class F2    

#Create a Low Path Filter
# filter response
#[W,h] = sig.freqz(b,a, worN=1024)
#W = Fs* W/(2*pi)
Fs = 50;
o = 8;
fc = np.array([14]) #Cut Off Frequncy
wc = 2*fc/Fs;
[b,a] = sig.butter(o, wc, btype = 'lowpass')

#BUILD FILE LIST FOR PROCESSING
Files=[]
for i in range(len(mainarray['File Name'])):
    Files.append(mainarray['File Name'][i])

# %%
#   MODIFY CHANNEL RAW DATA BY WELD CLASS  
#Take actual data in CSV , and multiply line by line with the Correction factors.

def modifyChannelDataintoStress(Channel):
    ChannelData ={
                            'actualData' :Channel,
                            'stressData' :[]
                        }   
    if Channel.name in Slot1:
        for actualData in Channel :
            if str(actualData) !='nan':
                modifiedData = float(actualData)*Corr1 
                ChannelData['stressData'].append(modifiedData)
            else:
                print('nan erros here , too many should be investigated.')
    else:
        for actualData in Channel:
            if str(actualData) !='nan':
                modifiedData = float(actualData)*Corr2
                ChannelData['stressData'].append(modifiedData)
            else:
                print('nan erros here , too many should be investigated.')
    return ChannelData

# %%
#Package The Filtered Signal
def FilteredSignal(Channel):
    #Work was done here to understand the use of filtering , however this was discarded , and not well documented.
    #At this point , there is no signal filtering , only date as modified in the getchannel data.
    #x_filt = sig.filtfilt(b,a, GetChannelData(Channel)) # forward and backward
    #x_filt = sig.lfilter(b,a, GetChannelData(Channel)) # Forward only
    x_filt =  modifyChannelDataintoStress(Channel) #turn data into stress with correction factors
    TimeLength=len(x_filt['stressData'])#get list count
    seq=[round(x,1) for x in range(1, TimeLength+1)] #create a running count from 0
    hz = 0.02 #1/0.02 = 50Hz capture rate of PMX
    x2= [round(x*hz,3) for x in range(0, TimeLength)]#this is create frequency time steps. it is a division of time
    dataFrameOfStressData={'count':seq,'timestep':x2,'stressData':x_filt['stressData'],'actualData':x_filt['actualData']}
    dataFrameOfStressData= pandas.DataFrame(dataFrameOfStressData, columns=['count','timestep', 'stressData','actualData'])
   
    #plot stress data
    t=dataFrameOfStressData['timestep']
    s2=dataFrameOfStressData['stressData']
    s3=dataFrameOfStressData['actualData']
 
    #plt.plot(t, s2,t, s3) # plot the filtered results.  
    #plt.xlabel("Time (s)")
    #plt.ylabel("Stress (MPa)")
    return dataFrameOfStressData

# %%
#RainFlow Counting
def RainFlow(Filtered, Channel):
    RainFlow_Results =[] #Initialize an empty list to store the results of Rainflow Algorithm
    x = Filtered.timestep.tolist()
    y = round(Filtered['stressData'],3).tolist()
    # Rainflow Count Algorithm
    # Function count_cycles returns a sorted list of the load ranges and the corresponding number of cycles
    # 3 decimal digits is used for precision
    # Mean, Range , Cycle Count list use to store each point in 3-Dimension
    damage1 = 0 #50 % damage
    damage2 = 0 # 97.7 % damage
    # Detailed output, like cycle lows, highs or means, use extract_cycles
    for rng, mean, count, i_start, i_end in rainflow.extract_cycles(y): 
        # compute the 50 % damage 
        if rng != 0: # if the range is zero no computation
            if Channel in Slot1 :
                Nfw=10**(11.5662-3*np.log10(rng))
                Ni = (count/Nfw)*100
                damage1=damage1+Ni
            else:
                Nfw=10**(12.0900-3*np.log10(rng))
                Ni = (count/Nfw)*100
                damage1=damage1+Ni
            # Compute the 97.7 % damage
            if Channel in Slot1 :
                Nfw=10**(11.5662-0.1846*2-3*np.log10(rng))
                Ni = (count/Nfw)*100
                damage2=damage2+Ni
            else:
                Nfw=10**(12.090-0.2279*2-3*np.log10(rng))
                Ni = (count/Nfw)*100
                damage2=damage2+Ni
    print(Channel , ' dmg @50% prob. survival : ',damage1,' %', ' dmg @97.7% prob. survival : ',damage2,' %') 
    RainFlow_Results.append(damage1) # 50 % damage
    RainFlow_Results.append(damage2) # 97.7 % damage
    return RainFlow_Results

# %%
#Running the Script Section
#Reading CSV Files From Folder
#RawData = pandas.DataFrame() # Initialize an empty dataframe 
count = 0
for file_nameShort in Files:
    print(file_nameShort +" "+ str(count) + "/" + str(filecount))
    count = count+1
    with open(path+file_nameShort) as file:
        dataofCSV = pandas.read_csv(file, delimiter=';',low_memory=False, on_bad_lines='skip')
        dataofCSV = dataofCSV.drop(dataofCSV.tail(3).index)
        # Calling the function on each Filename
        for Channel in Channels:
            dataframeOfFilteredData = FilteredSignal(dataofCSV[Channel]) # call the filtering the data and output a dataframe
            ab2 = RainFlow(dataframeOfFilteredData,Channel) # using the filtered data return a list of damages 
            #Assign outputs to JSONStructure
            #1. Find the File name in the JSONStructure we are looking for.
            for i in JSONStructure:
                if i['File']['file name'] == file_nameShort:
                    #2. Find the Channel Name We are looking for in the JSONStructure.
                    for j in i['File']['Channel Data']:
                        if j['Channel Name'] == Channel:
                            #3. Assign the Data
                            j['50 Damage'] = ab2[0]
                            j['97 Damage'] = ab2[1]
                            j['Minimum Stress']=dataframeOfFilteredData.min()[2]
                            j['Maximum Stress']=dataframeOfFilteredData.max()[2] 
            file.close()
print("complete")
# Out:
# 16-04-2023_00-59-07-691.csv 0/37
# Channel 1.1  dmg @50% prob. survival :  4.131770576645102e-07  %  dmg @97.7% prob. survival :  9.66799013523019e-07  %
# Channel 1.2  dmg @50% prob. survival :  4.603822840079511e-06  %  dmg @97.7% prob. survival :  1.0772552100020105e-05  %
# Channel 1.3  dmg @50% prob. survival :  8.806336319894009e-07  %  dmg @97.7% prob. survival :  2.0606074584467425e-06  %
# Channel 1.4  dmg @50% prob. survival :  2.646754871674456e-07  %  dmg @97.7% prob. survival :  6.193180263772997e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.0622121067505436e-05  %  dmg @97.7% prob. survival :  3.033969754837521e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0004668851721428769  %  dmg @97.7% prob. survival :  0.0013335523877585824  %
# Channel 2.4  dmg @50% prob. survival :  0.000409371248946001  %  dmg @97.7% prob. survival :  0.0011692768138385707  %
# 16-04-2023_06-59-07-731.csv 1/37
# Channel 1.1  dmg @50% prob. survival :  2.268110688158203e-07  %  dmg @97.7% prob. survival :  5.307185225300317e-07  %
# Channel 1.2  dmg @50% prob. survival :  1.7584558326047642e-06  %  dmg @97.7% prob. survival :  4.114636407685011e-06  %
# Channel 1.3  dmg @50% prob. survival :  7.854312296697452e-07  %  dmg @97.7% prob. survival :  1.8378419710111903e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.5044799575978308e-07  %  dmg @97.7% prob. survival :  3.5203545595955174e-07  %
# Channel 2.1  dmg @50% prob. survival :  6.5357292327317044e-06  %  dmg @97.7% prob. survival :  1.866783921204494e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00010525922631821801  %  dmg @97.7% prob. survival :  0.0003006492837330303  %
# Channel 2.4  dmg @50% prob. survival :  8.260510455940028e-05  %  dmg @97.7% prob. survival :  0.0002359428848867971  %
# 16-04-2023_12-59-07-769.csv 2/37
# Channel 1.1  dmg @50% prob. survival :  2.669571758976746e-07  %  dmg @97.7% prob. survival :  6.246569830608918e-07  %
# Channel 1.2  dmg @50% prob. survival :  1.7292904671772145e-06  %  dmg @97.7% prob. survival :  4.0463919444424895e-06  %
# Channel 1.3  dmg @50% prob. survival :  7.837966475798323e-07  %  dmg @97.7% prob. survival :  1.8340171885778317e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.7766745823713698e-07  %  dmg @97.7% prob. survival :  4.1572667255429987e-07  %
# Channel 2.1  dmg @50% prob. survival :  5.8202927857223696e-06  %  dmg @97.7% prob. survival :  1.6624356062174355e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0001049719516523786  %  dmg @97.7% prob. survival :  0.0002998287483221232  %
# Channel 2.4  dmg @50% prob. survival :  8.215132607852676e-05  %  dmg @97.7% prob. survival :  0.0002346467688120438  %
# 16-04-2023_18-59-07-809.csv 3/37
# Channel 1.1  dmg @50% prob. survival :  4.951134298527104e-07  %  dmg @97.7% prob. survival :  1.158523123886087e-06  %
# Channel 1.2  dmg @50% prob. survival :  2.5438859480572245e-06  %  dmg @97.7% prob. survival :  5.952475771522499e-06  %
# Channel 1.3  dmg @50% prob. survival :  8.824264987043838e-07  %  dmg @97.7% prob. survival :  2.06480261337922e-06  %
# Channel 1.4  dmg @50% prob. survival :  3.430196804734914e-07  %  dmg @97.7% prob. survival :  8.02636745068337e-07  %
# Channel 2.1  dmg @50% prob. survival :  7.975483998282e-06  %  dmg @97.7% prob. survival :  2.2780174578311062e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0001816884027375926  %  dmg @97.7% prob. survival :  0.0005189520202296552  %
# Channel 2.4  dmg @50% prob. survival :  0.00015101248195639738  %  dmg @97.7% prob. survival :  0.00043133315836538656  %
# 17-04-2023_00-59-07-849.csv 4/37
# Channel 1.1  dmg @50% prob. survival :  1.8164278379671733e-07  %  dmg @97.7% prob. survival :  4.250285947157533e-07  %
# Channel 1.2  dmg @50% prob. survival :  4.21797712658191e-06  %  dmg @97.7% prob. survival :  9.86970609668553e-06  %
# Channel 1.3  dmg @50% prob. survival :  7.65605325611487e-07  %  dmg @97.7% prob. survival :  1.7914510494192738e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.181910627565081e-07  %  dmg @97.7% prob. survival :  2.765569887307978e-07  %
# Channel 2.1  dmg @50% prob. survival :  9.873698185348162e-06  %  dmg @97.7% prob. survival :  2.820199607249455e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00041486241520676144  %  dmg @97.7% prob. survival :  0.0011849610940760369  %
# Channel 2.4  dmg @50% prob. survival :  0.0003611702624427545  %  dmg @97.7% prob. survival :  0.001031601547030002  %
# 17-04-2023_06-59-07-889.csv 5/37
# Channel 1.1  dmg @50% prob. survival :  2.275758181415461e-07  %  dmg @97.7% prob. survival :  5.325079706130015e-07  %
# Channel 1.2  dmg @50% prob. survival :  1.7285152513121835e-06  %  dmg @97.7% prob. survival :  4.0445780055518555e-06  %
# Channel 1.3  dmg @50% prob. survival :  7.64439254545943e-07  %  dmg @97.7% prob. survival :  1.788722542753792e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.5349873817756354e-07  %  dmg @97.7% prob. survival :  3.591739325648236e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.220402344200434e-05  %  dmg @97.7% prob. survival :  3.485804555895202e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00011874534105119689  %  dmg @97.7% prob. survival :  0.0003391693344367548  %
# Channel 2.4  dmg @50% prob. survival :  9.103183553297374e-05  %  dmg @97.7% prob. survival :  0.0002600119448641142  %
# 17-04-2023_12-59-07-912.csv 6/37
# Channel 1.1  dmg @50% prob. survival :  2.929985216838017e-07  %  dmg @97.7% prob. survival :  6.855915072553466e-07  %
# Channel 1.2  dmg @50% prob. survival :  1.6557930886658778e-06  %  dmg @97.7% prob. survival :  3.874414358264787e-06  %
# Channel 1.3  dmg @50% prob. survival :  7.924212784838764e-07  %  dmg @97.7% prob. survival :  1.8541980880139102e-06  %
# Channel 1.4  dmg @50% prob. survival :  2.0305334343111432e-07  %  dmg @97.7% prob. survival :  4.7512747496496385e-07  %
# Channel 2.1  dmg @50% prob. survival :  7.393024822612054e-06  %  dmg @97.7% prob. survival :  2.1116511067811808e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0001019379710968381  %  dmg @97.7% prob. survival :  0.00029116286588320826  %
# Channel 2.4  dmg @50% prob. survival :  7.92429477657048e-05  %  dmg @97.7% prob. survival :  0.00022633964090354005  %
# 17-04-2023_18-59-07-947.csv 7/37
# Channel 1.1  dmg @50% prob. survival :  3.650529405020163e-07  %  dmg @97.7% prob. survival :  8.541926910366376e-07  %
# Channel 1.2  dmg @50% prob. survival :  0.14192628590392206  %  dmg @97.7% prob. survival :  0.332095382982835  %
# Channel 1.3  dmg @50% prob. survival :  0.2314215505118179  %  dmg @97.7% prob. survival :  0.5415066557848436  %
# Channel 1.4  dmg @50% prob. survival :  2.4708402650528115e-07  %  dmg @97.7% prob. survival :  5.781555114233563e-07  %
# Channel 2.1  dmg @50% prob. survival :  7.756155217439958e-06  %  dmg @97.7% prob. survival :  2.2153711291730183e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00013743136947918288  %  dmg @97.7% prob. survival :  0.00039254176799143173  %
# Channel 2.4  dmg @50% prob. survival :  0.00011119186926639271  %  dmg @97.7% prob. survival :  0.00031759454274166675  %
# 18-04-2023_00-59-07-969.csv 8/37
# Channel 1.1  dmg @50% prob. survival :  26314089598603.625  %  dmg @97.7% prob. survival :  61572721412681.07  %
# Channel 1.2  dmg @50% prob. survival :  0.4258186070315315  %  dmg @97.7% prob. survival :  0.9963791589612893  %
# Channel 1.3  dmg @50% prob. survival :  0.6944501845327898  %  dmg @97.7% prob. survival :  1.6249540987155062  %
# Channel 1.4  dmg @50% prob. survival :  8.938186431581545e-08  %  dmg @97.7% prob. survival :  2.0914592580675664e-07  %
# Channel 2.1  dmg @50% prob. survival :  2.1756963135683762e-05  %  dmg @97.7% prob. survival :  6.214386721001138e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0002228665692849159  %  dmg @97.7% prob. survival :  0.0006365681828305138  %
# Channel 2.4  dmg @50% prob. survival :  0.0001902247481580563  %  dmg @97.7% prob. survival :  0.0005433341691977597  %
# 18-04-2023_06-59-07-992.csv 9/37
# Channel 1.1  dmg @50% prob. survival :  3.880804796083539e-05  %  dmg @97.7% prob. survival :  9.080751650967963e-05  %
# Channel 1.2  dmg @50% prob. survival :  0.8793972985598569  %  dmg @97.7% prob. survival :  2.057714543851162  %
# Channel 1.3  dmg @50% prob. survival :  1.4437548093628925  %  dmg @97.7% prob. survival :  3.3782629010232563  %
# Channel 1.4  dmg @50% prob. survival :  0.000392052167772985  %  dmg @97.7% prob. survival :  0.0009173685760652229  %
# Channel 2.1  dmg @50% prob. survival :  0.005094332754361409  %  dmg @97.7% prob. survival :  0.014550814662706192  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00010322186752048589  %  dmg @97.7% prob. survival :  0.00029483002698308156  %
# Channel 2.4  dmg @50% prob. survival :  0.00015920195006749954  %  dmg @97.7% prob. survival :  0.0004547245303893009  %
# 18-04-2023_12-59-08-028.csv 10/37
# Channel 1.1  dmg @50% prob. survival :  1.0651911800701932e-08  %  dmg @97.7% prob. survival :  2.4924563525533674e-08  %
# Channel 1.2  dmg @50% prob. survival :  1.548977427912497e-06  %  dmg @97.7% prob. survival :  3.6244748383193176e-06  %
# Channel 1.3  dmg @50% prob. survival :  6.342729294927479e-07  %  dmg @97.7% prob. survival :  1.4841444634028693e-06  %
# Channel 1.4  dmg @50% prob. survival :  2.700793083314257e-09  %  dmg @97.7% prob. survival :  6.3196250620446465e-09  %
# Channel 2.1  dmg @50% prob. survival :  1.4763780140593698e-06  %  dmg @97.7% prob. survival :  4.216941430903673e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  9.30124671740234e-05  %  dmg @97.7% prob. survival :  0.0002656691732615384  %
# Channel 2.4  dmg @50% prob. survival :  7.545456412600603e-05  %  dmg @97.7% prob. survival :  0.0002155189758880238  %
# 18-04-2023_18-59-08-052.csv 11/37
# Channel 1.1  dmg @50% prob. survival :  1.0618281177644228e-08  %  dmg @97.7% prob. survival :  2.4845870740948673e-08  %
# Channel 1.2  dmg @50% prob. survival :  1.7657310930230263e-06  %  dmg @97.7% prob. survival :  4.131659895473027e-06  %
# Channel 1.3  dmg @50% prob. survival :  6.342254236093709e-07  %  dmg @97.7% prob. survival :  1.484033303694629e-06  %
# Channel 1.4  dmg @50% prob. survival :  6.159075751634508e-10  %  dmg @97.7% prob. survival :  1.441171103389161e-09  %
# Channel 2.1  dmg @50% prob. survival :  1.4745587330362835e-06  %  dmg @97.7% prob. survival :  4.211745064222644e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00011020331316295159  %  dmg @97.7% prob. survival :  0.00031477095477866425  %
# Channel 2.4  dmg @50% prob. survival :  8.976380415563443e-05  %  dmg @97.7% prob. survival :  0.00025639009869741944  %
# 19-04-2023_00-59-08-088.csv 12/37
# Channel 1.1  dmg @50% prob. survival :  1.0387861185182966e-08  %  dmg @97.7% prob. survival :  2.4306707645428518e-08  %
# Channel 1.2  dmg @50% prob. survival :  2.5577696976717128e-06  %  dmg @97.7% prob. survival :  5.984962559407268e-06  %
# Channel 1.3  dmg @50% prob. survival :  6.227144848914255e-07  %  dmg @97.7% prob. survival :  1.4570986905770553e-06  %
# Channel 1.4  dmg @50% prob. survival :  8.085989305209637e-10  %  dmg @97.7% prob. survival :  1.8920524115790403e-09  %
# Channel 2.1  dmg @50% prob. survival :  1.9934085998543913e-06  %  dmg @97.7% prob. survival :  5.693722903886197e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00020475333022485916  %  dmg @97.7% prob. survival :  0.0005848317931574008  %
# Channel 2.4  dmg @50% prob. survival :  0.00017667054740970307  %  dmg @97.7% prob. survival :  0.0005046196461188349  %
# 19-04-2023_06-59-08-111.csv 13/37
# Channel 1.1  dmg @50% prob. survival :  2.898743779280811e-08  %  dmg @97.7% prob. survival :  6.782812777903608e-08  %
# Channel 1.2  dmg @50% prob. survival :  1.3714369039205093e-06  %  dmg @97.7% prob. survival :  3.20904518105268e-06  %
# Channel 1.3  dmg @50% prob. survival :  5.914162524237826e-07  %  dmg @97.7% prob. survival :  1.3838635006907972e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.7305743773732467e-08  %  dmg @97.7% prob. survival :  4.049396184602816e-08  %
# Channel 2.1  dmg @50% prob. survival :  2.9487843503855146e-06  %  dmg @97.7% prob. survival :  8.422538658475788e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  9.454486255925305e-05  %  dmg @97.7% prob. survival :  0.0002700461157024095  %
# Channel 2.4  dmg @50% prob. survival :  7.592598652730587e-05  %  dmg @97.7% prob. survival :  0.00021686548784944165  %
# 19-04-2023_12-59-08-151.csv 14/37
# Channel 1.1  dmg @50% prob. survival :  1.8506650239981944e-09  %  dmg @97.7% prob. survival :  4.3303980372896346e-09  %
# Channel 1.2  dmg @50% prob. survival :  1.1627404622869836e-06  %  dmg @97.7% prob. survival :  2.720713338433819e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.846457892621719e-07  %  dmg @97.7% prob. survival :  1.1340297392485225e-06  %
# Channel 1.4  dmg @50% prob. survival :  4.711891089669664e-10  %  dmg @97.7% prob. survival :  1.1025422570845558e-09  %
# Channel 2.1  dmg @50% prob. survival :  1.2616723290544733e-06  %  dmg @97.7% prob. survival :  3.603682976819114e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  9.31730914141317e-05  %  dmg @97.7% prob. survival :  0.00026612796024324284  %
# Channel 2.4  dmg @50% prob. survival :  7.47921736300365e-05  %  dmg @97.7% prob. survival :  0.00021362700655544025  %
# 19-04-2023_18-59-08-188.csv 15/37
# Channel 1.1  dmg @50% prob. survival :  7.118242204626699e-10  %  dmg @97.7% prob. survival :  1.6656078583723426e-09  %
# Channel 1.2  dmg @50% prob. survival :  1.705060532384316e-06  %  dmg @97.7% prob. survival :  3.989695967206931e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.490896171913174e-07  %  dmg @97.7% prob. survival :  1.0508313344845627e-06  %
# Channel 1.4  dmg @50% prob. survival :  5.906445513381259e-10  %  dmg @97.7% prob. survival :  1.3820577860848087e-09  %
# Channel 2.1  dmg @50% prob. survival :  1.6253041605959793e-06  %  dmg @97.7% prob. survival :  4.642315441824173e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00016171639219836982  %  dmg @97.7% prob. survival :  0.0004619064682780364  %
# Channel 2.4  dmg @50% prob. survival :  0.00013602991335708836  %  dmg @97.7% prob. survival :  0.0003885388240782947  %
# 20-04-2023_00-59-08-210.csv 16/37
# Channel 1.1  dmg @50% prob. survival :  6.123276847393366e-09  %  dmg @97.7% prob. survival :  1.4327944656588572e-08  %
# Channel 1.2  dmg @50% prob. survival :  2.607838653068725e-06  %  dmg @97.7% prob. survival :  6.102119637197555e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.4902985362367485e-07  %  dmg @97.7% prob. survival :  1.0506914928423872e-06  %
# Channel 1.4  dmg @50% prob. survival :  4.853237258107313e-09  %  dmg @97.7% prob. survival :  1.1356160528501965e-08  %
# Channel 2.1  dmg @50% prob. survival :  3.4621384458419777e-06  %  dmg @97.7% prob. survival :  9.888819064465782e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00028061734973634854  %  dmg @97.7% prob. survival :  0.000801520286176265  %
# Channel 2.4  dmg @50% prob. survival :  0.0002428852070558056  %  dmg @97.7% prob. survival :  0.0006937469149725277  %
# 20-04-2023_06-59-08-249.csv 17/37
# Channel 1.1  dmg @50% prob. survival :  6.91276348057981e-09  %  dmg @97.7% prob. survival :  1.6175275925341546e-08  %
# Channel 1.2  dmg @50% prob. survival :  1.2347227498310287e-06  %  dmg @97.7% prob. survival :  2.8891457411962023e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.5817326319798316e-07  %  dmg @97.7% prob. survival :  1.0720862900429872e-06  %
# Channel 1.4  dmg @50% prob. survival :  5.480278468976282e-09  %  dmg @97.7% prob. survival :  1.28233833881954e-08  %
# Channel 2.1  dmg @50% prob. survival :  1.4066437727963827e-06  %  dmg @97.7% prob. survival :  4.017761269499842e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00010312464832922465  %  dmg @97.7% prob. survival :  0.000294552342249495  %
# Channel 2.4  dmg @50% prob. survival :  8.410069673196386e-05  %  dmg @97.7% prob. survival :  0.00024021470723593351  %
# 20-04-2023_12-59-08-309.csv 18/37
# Channel 1.1  dmg @50% prob. survival :  3.3414244568471534e-09  %  dmg @97.7% prob. survival :  7.81864774123951e-09  %
# Channel 1.2  dmg @50% prob. survival :  2.02827259368449e-06  %  dmg @97.7% prob. survival :  4.74598457575114e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.4879701322656857e-07  %  dmg @97.7% prob. survival :  1.0501466662068473e-06  %
# Channel 1.4  dmg @50% prob. survival :  2.6724935609120885e-09  %  dmg @97.7% prob. survival :  6.253406597503374e-09  %
# Channel 2.1  dmg @50% prob. survival :  1.7715205290008993e-06  %  dmg @97.7% prob. survival :  5.059949581543392e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00020263308141431786  %  dmg @97.7% prob. survival :  0.0005787757797463469  %
# Channel 2.4  dmg @50% prob. survival :  0.00017448056027800105  %  dmg @97.7% prob. survival :  0.000498364440893048  %
# 20-04-2023_18-59-08-330.csv 19/37
# Channel 1.1  dmg @50% prob. survival :  1.3469254480242793e-09  %  dmg @97.7% prob. survival :  3.1516904684884595e-09  %
# Channel 1.2  dmg @50% prob. survival :  4.29552133386238e-06  %  dmg @97.7% prob. survival :  1.0051152916427079e-05  %
# Channel 1.3  dmg @50% prob. survival :  4.4197253798190894e-07  %  dmg @97.7% prob. survival :  1.0341779772103204e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.1088727940748546e-09  %  dmg @97.7% prob. survival :  2.5946675972141845e-09  %
# Channel 2.1  dmg @50% prob. survival :  3.264276552062646e-06  %  dmg @97.7% prob. survival :  9.323671108097758e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0005450997056626664  %  dmg @97.7% prob. survival :  0.0015569545948881432  %
# Channel 2.4  dmg @50% prob. survival :  0.0004831943710780865  %  dmg @97.7% prob. survival :  0.0013801359429456456  %
# 21-04-2023_00-59-08-369.csv 20/37
# Channel 1.1  dmg @50% prob. survival :  1.7480820505209599e-09  %  dmg @97.7% prob. survival :  4.090362643933991e-09  %
# Channel 1.2  dmg @50% prob. survival :  5.546216040134531e-06  %  dmg @97.7% prob. survival :  1.2977671671068078e-05  %
# Channel 1.3  dmg @50% prob. survival :  4.3818862164778937e-07  %  dmg @97.7% prob. survival :  1.025323936282262e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.3929309187283838e-09  %  dmg @97.7% prob. survival :  3.259339339277229e-09  %
# Channel 2.1  dmg @50% prob. survival :  4.249898796085008e-06  %  dmg @97.7% prob. survival :  1.2138879162166822e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0007481441446214982  %  dmg @97.7% prob. survival :  0.0021369053248542933  %
# Channel 2.4  dmg @50% prob. survival :  0.0006674132106118643  %  dmg @97.7% prob. survival :  0.0019063155862245266  %
# 21-04-2023_06-59-08-390.csv 21/37
# Channel 1.1  dmg @50% prob. survival :  7.375215399112383e-09  %  dmg @97.7% prob. survival :  1.7257373903303887e-08  %
# Channel 1.2  dmg @50% prob. survival :  1.5149891207223777e-06  %  dmg @97.7% prob. survival :  3.544945103419767e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.606107476537523e-07  %  dmg @97.7% prob. survival :  1.0777897954134628e-06  %
# Channel 1.4  dmg @50% prob. survival :  5.857515287551647e-09  %  dmg @97.7% prob. survival :  1.370608531294546e-08  %
# Channel 2.1  dmg @50% prob. survival :  1.5975102082610286e-06  %  dmg @97.7% prob. survival :  4.562928274030028e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00014829831861824935  %  dmg @97.7% prob. survival :  0.0004235807618098778  %
# Channel 2.4  dmg @50% prob. survival :  0.00012607410080721628  %  dmg @97.7% prob. survival :  0.0003601022868093989  %
# 21-04-2023_12-59-08-429.csv 22/37
# Channel 1.1  dmg @50% prob. survival :  1.3242641479120317e-09  %  dmg @97.7% prob. survival :  3.0986649623810873e-09  %
# Channel 1.2  dmg @50% prob. survival :  3.5303596312660497e-07  %  dmg @97.7% prob. survival :  8.260739906959659e-07  %
# Channel 1.3  dmg @50% prob. survival :  4.54548960270477e-07  %  dmg @97.7% prob. survival :  1.0636057308492493e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.0904586656720958e-09  %  dmg @97.7% prob. survival :  2.5515801100362548e-09  %
# Channel 2.1  dmg @50% prob. survival :  5.328929651445937e-07  %  dmg @97.7% prob. survival :  1.522088788609949e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  1.5601720552120966e-05  %  dmg @97.7% prob. survival :  4.456280245512854e-05  %
# Channel 2.4  dmg @50% prob. survival :  1.3484702673094124e-05  %  dmg @97.7% prob. survival :  3.85160174725421e-05  %
# 21-04-2023_18-59-08-450.csv 23/37
# Channel 1.1  dmg @50% prob. survival :  4.766584850807981e-10  %  dmg @97.7% prob. survival :  1.1153401298910404e-09  %
# Channel 1.2  dmg @50% prob. survival :  1.576366599549317e-08  %  dmg @97.7% prob. survival :  3.688563159846483e-08  %
# Channel 1.3  dmg @50% prob. survival :  4.262660567168432e-08  %  dmg @97.7% prob. survival :  9.974261529953393e-08  %
# Channel 1.4  dmg @50% prob. survival :  3.77393950343396e-10  %  dmg @97.7% prob. survival :  8.830695996626316e-10  %
# Channel 2.1  dmg @50% prob. survival :  3.97505776395564e-08  %  dmg @97.7% prob. survival :  1.1353857626860604e-07  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  2.381340263498219e-08  %  dmg @97.7% prob. survival :  6.801762368847472e-08  %
# Channel 2.4  dmg @50% prob. survival :  1.1403605660034594e-08  %  dmg @97.7% prob. survival :  3.2571832356983605e-08  %
# 27-04-2023_23-46-50-249.csv 24/37
# Channel 1.1  dmg @50% prob. survival :  7.578082366966151e-10  %  dmg @97.7% prob. survival :  1.7732065275339047e-09  %
# Channel 1.2  dmg @50% prob. survival :  2.3888876065567465e-06  %  dmg @97.7% prob. survival :  5.589792895305855e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.4671569016668645e-07  %  dmg @97.7% prob. survival :  1.045276548072739e-06  %
# Channel 1.4  dmg @50% prob. survival :  6.434693783827731e-10  %  dmg @97.7% prob. survival :  1.5056633680712587e-09  %
# Channel 2.1  dmg @50% prob. survival :  1.9048686403900577e-06  %  dmg @97.7% prob. survival :  5.440828442034655e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00025162121613753386  %  dmg @97.7% prob. survival :  0.0007186993582402486  %
# Channel 2.4  dmg @50% prob. survival :  0.00021800509572991275  %  dmg @97.7% prob. survival :  0.0006226824780489247  %
# 28-04-2023_05-46-50-272.csv 25/37
# Channel 1.1  dmg @50% prob. survival :  1.663530446685507e-08  %  dmg @97.7% prob. survival :  3.892519114957096e-08  %
# Channel 1.2  dmg @50% prob. survival :  1.38675264075899e-06  %  dmg @97.7% prob. survival :  3.2448826966945416e-06  %
# Channel 1.3  dmg @50% prob. survival :  0.0001234599263884291  %  dmg @97.7% prob. survival :  0.00028888567946311203  %
# Channel 1.4  dmg @50% prob. survival :  1.277121065167783e-08  %  dmg @97.7% prob. survival :  2.988354176615893e-08  %
# Channel 2.1  dmg @50% prob. survival :  3.2062953196436842e-06  %  dmg @97.7% prob. survival :  9.158060770586896e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00013327299374142664  %  dmg @97.7% prob. survival :  0.00038066430384150514  %
# Channel 2.4  dmg @50% prob. survival :  0.0001087670892420334  %  dmg @97.7% prob. survival :  0.000310668704475243  %
# 28-04-2023_11-46-50-310.csv 26/37
# Channel 1.1  dmg @50% prob. survival :  8.261079524653474e-09  %  dmg @97.7% prob. survival :  1.933022026977035e-08  %
# Channel 1.2  dmg @50% prob. survival :  1.1127743155591346e-06  %  dmg @97.7% prob. survival :  2.603796824145512e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.755102082950077e-07  %  dmg @97.7% prob. survival :  1.112653260319791e-06  %
# Channel 1.4  dmg @50% prob. survival :  5.618223603041283e-09  %  dmg @97.7% prob. survival :  1.3146163216010724e-08  %
# Channel 2.1  dmg @50% prob. survival :  2.5135614095397167e-06  %  dmg @97.7% prob. survival :  7.179422306529097e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  9.473234284324597e-05  %  dmg @97.7% prob. survival :  0.0002705816109275721  %
# Channel 2.4  dmg @50% prob. survival :  7.464073951581107e-05  %  dmg @97.7% prob. survival :  0.00021319446909941984  %
# 28-04-2023_17-46-50-350.csv 27/37
# Channel 1.1  dmg @50% prob. survival :  4.68929435755562e-10  %  dmg @97.7% prob. survival :  1.097254814833134e-09  %
# Channel 1.2  dmg @50% prob. survival :  1.3398744260157138e-06  %  dmg @97.7% prob. survival :  3.1351916794200437e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.5148598397649e-07  %  dmg @97.7% prob. survival :  1.0564386280188377e-06  %
# Channel 1.4  dmg @50% prob. survival :  4.014893909428451e-10  %  dmg @97.7% prob. survival :  9.39450871978215e-10  %
# Channel 2.1  dmg @50% prob. survival :  1.2355325226305052e-06  %  dmg @97.7% prob. survival :  3.5290205044331085e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00011502739149446621  %  dmg @97.7% prob. survival :  0.00032854984852288805  %
# Channel 2.4  dmg @50% prob. survival :  9.380159389841147e-05  %  dmg @97.7% prob. survival :  0.0002679231360993856  %
# 28-04-2023_23-46-50-387.csv 28/37
# Channel 1.1  dmg @50% prob. survival :  8.899409461844329e-10  %  dmg @97.7% prob. survival :  2.082385778456559e-09  %
# Channel 1.2  dmg @50% prob. survival :  2.8386381269144308e-06  %  dmg @97.7% prob. survival :  6.6421706867331725e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.451113022747507e-07  %  dmg @97.7% prob. survival :  1.0415224174828454e-06  %
# Channel 1.4  dmg @50% prob. survival :  7.509950822539348e-10  %  dmg @97.7% prob. survival :  1.75726432824656e-09  %
# Channel 2.1  dmg @50% prob. survival :  2.145130102749892e-06  %  dmg @97.7% prob. survival :  6.127081220947911e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.000311463736020369  %  dmg @97.7% prob. survival :  0.0008896260443737702  %
# Channel 2.4  dmg @50% prob. survival :  0.0002712848651018395  %  dmg @97.7% prob. survival :  0.0007748641447723415  %
# 29-04-2023_05-46-50-408.csv 29/37
# Channel 1.1  dmg @50% prob. survival :  7.079322802693371e-10  %  dmg @97.7% prob. survival :  1.65650105084442e-09  %
# Channel 1.2  dmg @50% prob. survival :  1.5366975079760865e-06  %  dmg @97.7% prob. survival :  3.5957408748518055e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.5718506434062574e-07  %  dmg @97.7% prob. survival :  1.0697739891474929e-06  %
# Channel 1.4  dmg @50% prob. survival :  5.585964154019393e-10  %  dmg @97.7% prob. survival :  1.3070678861535235e-09  %
# Channel 2.1  dmg @50% prob. survival :  1.4374025619080922e-06  %  dmg @97.7% prob. survival :  4.105616826094642e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00014396922106327885  %  dmg @97.7% prob. survival :  0.0004112156692223903  %
# Channel 2.4  dmg @50% prob. survival :  0.00012084499096360068  %  dmg @97.7% prob. survival :  0.00034516651173263353  %
# 29-04-2023_11-46-50-431.csv 30/37
# Channel 1.1  dmg @50% prob. survival :  9.042783267691197e-08  %  dmg @97.7% prob. survival :  2.115934024051908e-07  %
# Channel 1.2  dmg @50% prob. survival :  1.4209165901488185e-06  %  dmg @97.7% prob. survival :  3.324823419334948e-06  %
# Channel 1.3  dmg @50% prob. survival :  6.050705225525593e-07  %  dmg @97.7% prob. survival :  1.4158133261855713e-06  %
# Channel 1.4  dmg @50% prob. survival :  6.21426658567973e-08  %  dmg @97.7% prob. survival :  1.4540852870094627e-07  %
# Channel 2.1  dmg @50% prob. survival :  3.952591362787972e-06  %  dmg @97.7% prob. survival :  1.1289687409618537e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  9.733433964233123e-05  %  dmg @97.7% prob. survival :  0.00027801362901551336  %
# Channel 2.4  dmg @50% prob. survival :  7.680838230508817e-05  %  dmg @97.7% prob. survival :  0.0002193858527413261  %
# 29-04-2023_17-46-50-469.csv 31/37
# Channel 1.1  dmg @50% prob. survival :  8.057983339086739e-10  %  dmg @97.7% prob. survival :  1.8854992547867427e-09  %
# Channel 1.2  dmg @50% prob. survival :  2.448462810525596e-06  %  dmg @97.7% prob. survival :  5.729193782550648e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.4811065320763334e-07  %  dmg @97.7% prob. survival :  1.048540642404364e-06  %
# Channel 1.4  dmg @50% prob. survival :  6.8525420857023e-10  %  dmg @97.7% prob. survival :  1.6034363006579343e-09  %
# Channel 2.1  dmg @50% prob. survival :  1.910800473239646e-06  %  dmg @97.7% prob. survival :  5.457771387178921e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0002658102431568982  %  dmg @97.7% prob. survival :  0.0007592271196485168  %
# Channel 2.4  dmg @50% prob. survival :  0.0002299475742877738  %  dmg @97.7% prob. survival :  0.0006567934795259908  %
# 29-04-2023_23-46-50-491.csv 32/37
# Channel 1.1  dmg @50% prob. survival :  1.5021296307144672e-09  %  dmg @97.7% prob. survival :  3.514854995502186e-09  %
# Channel 1.2  dmg @50% prob. survival :  4.900778339352206e-06  %  dmg @97.7% prob. survival :  1.1467402596753373e-05  %
# Channel 1.3  dmg @50% prob. survival :  4.418726024642281e-07  %  dmg @97.7% prob. survival :  1.033944136637279e-06  %
# Channel 1.4  dmg @50% prob. survival :  1.24199137374225e-09  %  dmg @97.7% prob. survival :  2.9061537001253107e-09  %
# Channel 2.1  dmg @50% prob. survival :  3.644030923402715e-06  %  dmg @97.7% prob. survival :  1.0408353978486655e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0006448308499269527  %  dmg @97.7% prob. survival :  0.0018418141567308644  %
# Channel 2.4  dmg @50% prob. survival :  0.0005703624722823294  %  dmg @97.7% prob. survival :  0.0016291120005139357  %
# 30-04-2023_05-46-50-529.csv 33/37
# Channel 1.1  dmg @50% prob. survival :  8.717097724811888e-10  %  dmg @97.7% prob. survival :  2.0397263896421916e-09  %
# Channel 1.2  dmg @50% prob. survival :  1.8871590307675524e-06  %  dmg @97.7% prob. survival :  4.415790895119086e-06  %
# Channel 1.3  dmg @50% prob. survival :  4.59059255309897e-07  %  dmg @97.7% prob. survival :  1.07415943588667e-06  %
# Channel 1.4  dmg @50% prob. survival :  6.464947727892645e-10  %  dmg @97.7% prob. survival :  1.5127425324961817e-09  %
# Channel 2.1  dmg @50% prob. survival :  1.641811275249418e-06  %  dmg @97.7% prob. survival :  4.689464298705371e-06  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00019948953385595956  %  dmg @97.7% prob. survival :  0.0005697969438298417  %
# Channel 2.4  dmg @50% prob. survival :  0.00017059239332231133  %  dmg @97.7% prob. survival :  0.0004872587672988861  %
# 30-04-2023_11-46-50-551.csv 34/37
# Channel 1.1  dmg @50% prob. survival :  2.750754641452113e-07  %  dmg @97.7% prob. survival :  6.436530839423003e-07  %
# Channel 1.2  dmg @50% prob. survival :  1.4890238050123344e-06  %  dmg @97.7% prob. survival :  3.4841884831067734e-06  %
# Channel 1.3  dmg @50% prob. survival :  6.921563705995822e-07  %  dmg @97.7% prob. survival :  1.6195867700927478e-06  %
# Channel 1.4  dmg @50% prob. survival :  2.0028432696849733e-07  %  dmg @97.7% prob. survival :  4.686482130246211e-07  %
# Channel 2.1  dmg @50% prob. survival :  9.93853479935817e-06  %  dmg @97.7% prob. survival :  2.838718726421829e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0001100803868292033  %  dmg @97.7% prob. survival :  0.0003144198433798079  %
# Channel 2.4  dmg @50% prob. survival :  8.460787777782875e-05  %  dmg @97.7% prob. survival :  0.00024166335571544623  %
# 30-04-2023_17-46-50-590.csv 35/37
# Channel 1.1  dmg @50% prob. survival :  6.451571859188653e-07  %  dmg @97.7% prob. survival :  1.5096126935006447e-06  %
# Channel 1.2  dmg @50% prob. survival :  2.614591682980177e-06  %  dmg @97.7% prob. survival :  6.1179211502186516e-06  %
# Channel 1.3  dmg @50% prob. survival :  9.212202116820844e-07  %  dmg @97.7% prob. survival :  2.155576587253361e-06  %
# Channel 1.4  dmg @50% prob. survival :  4.809451506751002e-07  %  dmg @97.7% prob. survival :  1.1253705611332073e-06  %
# Channel 2.1  dmg @50% prob. survival :  9.983512883002403e-06  %  dmg @97.7% prob. survival :  2.8515657034563485e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.00019677792712321742  %  dmg @97.7% prob. survival :  0.0005620518496421577  %
# Channel 2.4  dmg @50% prob. survival :  0.0001614524400238233  %  dmg @97.7% prob. survival :  0.00046115254831306053  %
# 30-04-2023_23-46-50-628.csv 36/37
# Channel 1.1  dmg @50% prob. survival :  5.22580390573911e-07  %  dmg @97.7% prob. survival :  1.2227934652255088e-06  %
# Channel 1.2  dmg @50% prob. survival :  5.1492729347948585e-06  %  dmg @97.7% prob. survival :  1.2048858718973024e-05  %
# Channel 1.3  dmg @50% prob. survival :  8.863642346736373e-07  %  dmg @97.7% prob. survival :  2.0740165791112866e-06  %
# Channel 1.4  dmg @50% prob. survival :  3.884899850118281e-07  %  dmg @97.7% prob. survival :  9.090333727532758e-07  %
# Channel 2.1  dmg @50% prob. survival :  1.383752638535572e-05  %  dmg @97.7% prob. survival :  3.9523778977979195e-05  %
# Channel 2.2  dmg @50% prob. survival :  0  %  dmg @97.7% prob. survival :  0  %
# Channel 2.3  dmg @50% prob. survival :  0.0005560852164437281  %  dmg @97.7% prob. survival :  0.00158833223334598  %
# Channel 2.4  dmg @50% prob. survival :  0.00048552137266323853  %  dmg @97.7% prob. survival :  0.0013867824991126  %
# complete

# %%
#POST PROCESSING OF DATASET
dataset = []
channelList = ['Channel 1.1', 'Channel 1.2','Channel 1.3','Channel 1.4','Channel 2.1','Channel 2.2','Channel 2.3','Channel 2.4']
damage97 =[]
damage50 =[]
for j in range(len(Channels)):
    dataset.append({
        'name' : Channels[j],
        '50 Damage' : 0 ,
        '97 Damage':0,
        'Stress Range':[],
        'Maximum Stress Range':0,
    })  
for i in range(len(JSONStructure)):#Loop throguh the JSON object , and view each file name.
    for j in range(len(JSONStructure[i]['File']['Channel Data'])): #Loop through the channel data to view each channel dataset.      
        ChannelName = JSONStructure[i]['File']['Channel Data'][j]['Channel Name'] # define a variable to channelname.
        for j in range(len(Channels)):#Loop through the summary data array and find the place to put the data.
            if ChannelName == dataset[j]['name']:#Check that the right channel has been found.
                dataset[j]['50 Damage'] = dataset[j]['50 Damage'] + JSONStructure[i]['File']['Channel Data'][j]['50 Damage']#Add the data sets together into the storage array.
                dataset[j]['97 Damage'] = dataset[j]['97 Damage'] + JSONStructure[i]['File']['Channel Data'][j]['97 Damage']#Add the data sets together into the storage array.
                dataset[j]['Stress Range'].append(JSONStructure[i]['File']['Channel Data'][j]['Maximum Stress'] -JSONStructure[i]['File']['Channel Data'][j]['Minimum Stress']) # Calculate stress range 
                damage50.append(dataset[j]['50 Damage'])
                damage97.append(dataset[j]['97 Damage'])
#print(dataset)                
for i in range(len(dataset)):
    dataset[i]['Maximum Stress Range']  = max(dataset[i]['Stress Range']) 
    dataset[i].pop('Stress Range')

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot 50 Damage
ax1.set_title('50 Damage')
ax1.set_xlabel('Channel')
ax1.set_ylabel('Damage')
for i, data in enumerate(dataset):
    name = data["name"]
    damage_50 = data["50 Damage"]
    ax1.bar(i, damage_50, label=name)
ax1.legend()

# Plot 97 Damage
ax2.set_title('97 Damage')
ax2.set_xlabel('Channel')
ax2.set_ylabel('Damage')
for i, data in enumerate(dataset):
    name = data["name"]
    damage_97 = data["97 Damage"]
    ax2.bar(i, damage_97, label=name)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
#This cell is used to visually compare the local and cloud servers.
import pymongo
import datetime
from pymongo import MongoClient
import os
import pprint
import pandas as pd
import certifi

# Environment variable for MongoDB collection
COLLECTION_PROCCESSED_DATA = os.getenv('COLLECTION_PROCCESSED_DATA')

# Connect to the remote MongoDB database
user = os.getenv('MYSQL_USER')
password = os.getenv('MYSQL_PASSWORD')
remote_conn_text = f'mongodb+srv://{user}:{password}@entangelment.2vytk.mongodb.net/?retryWrites=true&w=majority'
remote_client = MongoClient(remote_conn_text, tlsCAFile=certifi.where())
remote_db = remote_client.entangelment
remote_collection = remote_db[COLLECTION_PROCCESSED_DATA]

# Fetch last 10 entries from the remote MongoDB
remote_last_entries = remote_collection.find().sort("_id", pymongo.DESCENDING).limit(10)

# Connect to the local MongoDB database
local_conn_text = 'mongodb://localhost:27017'
local_client = MongoClient(local_conn_text)
local_db = local_client.entangelment
local_collection = local_db[COLLECTION_PROCCESSED_DATA]

# Fetch last 10 entries from the local MongoDB
local_last_entries = local_collection.find().sort("_id", pymongo.DESCENDING).limit(10)

# Print "description" data from the remote database
print("Description from the Remote DB:")
for entry in remote_last_entries:
    print(entry.get('Description', "N/A"))

# Print "description" data from the local database
print("\nDescription from the Local DB:")
for entry in local_last_entries:
    print(entry.get('Description', "N/A"))
# Out:
# Description from the Remote DB:
# C:/Users/jdavi/Desktop/Lumpy April/d/
# C:/Users/jdavi/Desktop/Lumpy April/c/
# C:/Users/jdavi/Desktop/Lumpy April/b/
# Testing data set march 2023
# C:/Users/MY PC/Desktop/Lumpy/
# C:/Users/MY PC/Desktop/LUMPY/jun/b/
# C:/Users/MY PC/Desktop/LUMPY/jun/b/
# C:/Users/MY PC/Desktop/LUMPY/jun/a/
# C:/Users/MY PC/Desktop/LUMPY/may/f/
# C:/Users/MY PC/Desktop/LUMPY/may/e/
#
# Description from the Local DB:
# C:/Users/MY PC/Desktop/Lumpy/
# C:/Users/MY PC/Desktop/LUMPY/jun/b/
# C:/Users/MY PC/Desktop/LUMPY/jun/b/
# C:/Users/MY PC/Desktop/LUMPY/jun/a/
# C:/Users/MY PC/Desktop/LUMPY/may/f/
# C:/Users/MY PC/Desktop/LUMPY/may/e/
# C:/Users/MY PC/Desktop/LUMPY/may/d/
# C:/Users/MY PC/Desktop/LUMPY/may/c/
# C:/Users/MY PC/Desktop/LUMPY/may/b/
# C:/Users/MY PC/Desktop/LUMPY/may/a/

# %%
import pymongo #import the pymongo pip
import datetime
#mongodb://heroku_6x00zflw:muikokfevp1h13d5pu0ph74p21@ds161109.mlab.com:61109/heroku_6x00zflw
from pymongo import MongoClient
user = os.getenv('MYSQL_USER')
userPC = os.environ['COMPUTERNAME'] # WORK ONLY ON WINDOWS
password = os.getenv('MYSQL_PASSWORD')
host = os.getenv('MYSQL_HOST')
COLLECTION_PROCCESSED_DATA = os.getenv('COLLECTION_PROCCESSED_DATA')
conn_text = 'mongodb+srv://{}:{}@{}/?retryWrites=true&w=majority'.format(user,password,host)
client = MongoClient(conn_text, tlsCAFile=certifi.where())
db = client.entangelment
collection = db[COLLECTION_PROCCESSED_DATA]
post = {"author": userPC,
        "timestamp": datetime.datetime.utcnow(),
        "Description":path,
        'data':JSONStructure,
        'summary':dataset,
        
       }
post_id = collection.insert_one(post)
print('complete ' + path)
# Out:
# complete C:/Users/jdavi/Desktop/Lumpy April/d/

# %%
#Notes
# Should there be issues with the array struture above, here is he structure.:
example = {
  "File Name": [
    "03-05-2020_02-37-05-588.csv"
  ],
  "Channel": [
    "Channel 1.1",
    "Channel 1.2",
    "Channel 1.3",
    "Channel 1.4",
    "Channel 2.1",
    "Channel 2.2",
    "Channel 2.3",
    "Channel 2.4"
  ]
}
